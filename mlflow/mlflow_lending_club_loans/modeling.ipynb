# %%
###########################################################
### step  3 - training and prediction
# 
# Author: André V. Silva 2021-01-02
###########################################################

import time
from datetime import datetime

start_time = time.time()

# libraries for this project
import json
import pandas as pd
import numpy as np
from numpy import mean, std
from IPython.display import HTML
import matplotlib.pyplot as plt
from icecream import ic
#import seaborn as sns
import os.path
import sys
import gc
import feather
from icecream import ic
from sys import getsizeof
import time
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score
from matplotlib import pyplot
import seaborn as sns

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
import catboost as cb
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

import warnings

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet

import mlflow
import mlflow.sklearn

k_features = 6

def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

# This make machine learning interpretable and understandable to everyone.
# fshapashrom shapash.explainer.smart_explainer import SmartExplainer 

# Pandas has a high consume of memory RAM usage
# release memory RAM
def release_memory(df):   
    del df
    gc.collect() 
    df = pd.DataFrame() # point to NULL
    print('memory RAM released.')

# Get start time 
start_time = time.time()

def transf_cat_num(df):

    print("preprocessing: the categorical and numerical feature now...")
    categorical_feature_names = list(df.select_dtypes(include='category').columns)
    numeric_feature_names = list(df.drop(categorical_feature_names, axis=1).columns)
    
    print("One Hot Encoder...")
    print(f'categorical features: {categorical_feature_names}')
    
    categorical_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                                            ('onehot', OneHotEncoder(handle_unknown='ignore'))] )
    
    numeric_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
                                        ('scaler', StandardScaler())])

    # Two preprocessed steps together using the Column Transformer module
    preprocessor = ColumnTransformer(
    transformers=[('num', numeric_transformer, numeric_feature_names),
                  ('cat', categorical_transformer, categorical_feature_names)])
    
    return preprocessor


# Get start time 
start_time = time.time()

# datetime object containing current date and time
now = datetime.now()

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print(">>> date: ", dt_string)
# Out:
# >>> date:  03/09/2021 19:08:12

# %%
print("Loading dataset - to modeling...")

# loading data feather format
df = pd.read_feather('dataset_featureselect.ftr')

print(df)
print(df.dtypes)

# Alternatively X and y can be obtained directly from the dataframe attribute:
X = df.drop('median_house_value', axis=1) # drop the column target
y = df['median_house_value'] # target
# Out:
# Loading dataset - to modeling...
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20428    -121.09     39.48                25.0       1665.0           374.0
# 20429    -121.21     39.49                18.0        697.0           150.0
# 20430    -121.22     39.43                17.0       2254.0           485.0
# 20431    -121.32     39.43                18.0       1860.0           409.0
# 20432    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20428       845.0       330.0         1.5603             78100.0
# 20429       356.0       114.0         2.5568             77100.0
# 20430      1007.0       433.0         1.7000             92300.0
# 20431       741.0       349.0         1.8672             84700.0
# 20432      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20428          INLAND
# 20429          INLAND
# 20430          INLAND
# 20431          INLAND
# 20432          INLAND
#
# [20433 rows x 10 columns]
# longitude              float64
# latitude               float64
# housing_median_age     float64
# total_rooms            float64
# total_bedrooms         float64
# population             float64
# households             float64
# median_income          float64
# median_house_value     float64
# ocean_proximity       category
# dtype: object

# %%
## Pipeline
def pipeline_project(df, model):
    # Pipeline object
    print("setting the pipeline object ...")
    print('preprocessor...')
    preprocessor = transf_cat_num(df)

    feature_selection = SelectKBest(score_func=mutual_info_regression, k = 5) # f_regression

    pipe = Pipeline(steps=[('preprocessor', preprocessor),
                            ('fs', feature_selection),
                            ('scaler', StandardScaler()),
                            ('model', model)])

    print('>>> pipeline defined!')    
    return pipe

# %%
# Regression models
def get_models():
  models['RandomForest']=RandomForestRegressor(n_estimators=5, random_state = 42, n_jobs = -1)
  models['DecisionTree']=DecisionTreeRegressor()
  #models['KNR']=KNeighborsRegressor()
  models['XGBoost']=xgb.XGBRegressor(objective="reg:linear", random_state=42)
  models['CatBoost'] = cb.CatBoostRegressor(loss_function='RMSE')
  models['LinearR']= LinearRegression(n_jobs = -1) # Use all computer cores

  return models

# %%
models = dict()
models = get_models()

print(models)
# Out:
# {'RandomForest': RandomForestRegressor(n_estimators=5, n_jobs=-1, random_state=42), 'DecisionTree': DecisionTreeRegressor(), 'XGBoost': XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', random_state=42, reg_alpha=None,
#              reg_lambda=None, scale_pos_weight=None, subsample=None,
#              tree_method=None, validate_parameters=None, verbosity=None), 'CatBoost': <catboost.core.CatBoostRegressor object at 0x7f1c40372400>, 'LinearR': LinearRegression(n_jobs=-1)}

# %%
# evaluate the models and store results
results, names = list(), list()

for name, model in models.items():
    
    # Alternatively X and y can be obtained directly from the dataframe attribute:
    X = df.drop('median_house_value', axis=1) # drop the column target
    y = df['median_house_value'] # target

    pipe = pipeline_project(X, model)

    ## Split-out validation dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.14, random_state=1)

    ## Training the model
    #print('training the model...')

    ## Fitting...
    pipe.fit(X_train, y_train)

    ## prediction
    print('prediction...')
    y_pred = pipe.predict(X_test)

    scores = r2_score(y_test, y_pred)
    # store the results
    results.append(scores)

    ## model names
    names.append(name)
    
    # summarize the performance along the way
    print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))

    release_memory(X)
    release_memory(y)

# plot model performance for comparison
sns.boxplot(x=names, y=results, palette="Set3", linewidth=3, width=0.3)
plt.title("Models")
plt.ylabel("Scores") # MAE -- Mean Absolute Error
#sns.xlabel("Models")
plt.savefig('figures/scores_models.png')
plt.savefig('figures/scores_importance_models.pdf')
plt.show()
# Out:
# setting the pipeline object ...
# preprocessor...
# preprocessing: the categorical and numerical feature now...
# One Hot Encoder...
# categorical features: ['ocean_proximity']
# >>> pipeline defined!
# prediction...
# >RandomForest 0.810 (0.000)
# memory RAM released.
# memory RAM released.
# setting the pipeline object ...
# preprocessor...
# preprocessing: the categorical and numerical feature now...
# One Hot Encoder...
# categorical features: ['ocean_proximity']
# >>> pipeline defined!
# prediction...
# >DecisionTree 0.712 (0.000)
# memory RAM released.
# memory RAM released.
# setting the pipeline object ...
# preprocessor...
# preprocessing: the categorical and numerical feature now...
# One Hot Encoder...
# categorical features: ['ocean_proximity']
# >>> pipeline defined!
# [19:08:19] WARNING: ../src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# prediction...
# >XGBoost 0.836 (0.000)
# memory RAM released.
# memory RAM released.
# setting the pipeline object ...
# preprocessor...
# preprocessing: the categorical and numerical feature now...
# One Hot Encoder...
# categorical features: ['ocean_proximity']
# >>> pipeline defined!
# Learning rate set to 0.06501
# 0:	learn: 110895.7528976	total: 5.22ms	remaining: 5.21s
# 1:	learn: 106886.1045968	total: 9.37ms	remaining: 4.67s
# 2:	learn: 103095.7444187	total: 13.8ms	remaining: 4.59s
# 3:	learn: 99937.4915267	total: 17.1ms	remaining: 4.25s
# 4:	learn: 96877.3283073	total: 21.8ms	remaining: 4.34s
# 5:	learn: 94073.4984793	total: 27ms	remaining: 4.46s
# 6:	learn: 91628.7271475	total: 31.9ms	remaining: 4.53s
# 7:	learn: 89305.9837333	total: 35.8ms	remaining: 4.44s
# 8:	learn: 87308.9902292	total: 39.8ms	remaining: 4.39s
# 9:	learn: 85252.9998345	total: 43.8ms	remaining: 4.33s
# 10:	learn: 83532.4462303	total: 48.8ms	remaining: 4.38s
# 11:	learn: 81926.8178778	total: 54.4ms	remaining: 4.48s
# 12:	learn: 80449.6666229	total: 59.1ms	remaining: 4.49s
# 13:	learn: 78942.3768736	total: 63.6ms	remaining: 4.48s
# 14:	learn: 77657.8273005	total: 67.6ms	remaining: 4.44s
# 15:	learn: 76625.8614793	total: 71.5ms	remaining: 4.4s
# 16:	learn: 75651.2226269	total: 76ms	remaining: 4.39s
# 17:	learn: 74615.6362971	total: 79.7ms	remaining: 4.35s
# 18:	learn: 73639.1579437	total: 83.4ms	remaining: 4.31s
# 19:	learn: 72907.2890495	total: 87.1ms	remaining: 4.27s
# 20:	learn: 72140.9326738	total: 91.1ms	remaining: 4.25s
# 21:	learn: 71455.9960148	total: 95.2ms	remaining: 4.23s
# 22:	learn: 70768.2115111	total: 99.2ms	remaining: 4.21s
# 23:	learn: 70143.0669272	total: 103ms	remaining: 4.2s
# 24:	learn: 69560.9931649	total: 107ms	remaining: 4.19s
# 25:	learn: 69110.0527158	total: 112ms	remaining: 4.2s
# 26:	learn: 68704.5992150	total: 116ms	remaining: 4.19s
# 27:	learn: 68356.2097231	total: 120ms	remaining: 4.18s
# 28:	learn: 68037.1378553	total: 125ms	remaining: 4.18s
# 29:	learn: 67685.1033679	total: 130ms	remaining: 4.19s
# 30:	learn: 67341.7332219	total: 134ms	remaining: 4.19s
# 31:	learn: 66980.4885370	total: 139ms	remaining: 4.2s
# 32:	learn: 66623.9821872	total: 143ms	remaining: 4.19s
# 33:	learn: 66214.4560806	total: 148ms	remaining: 4.2s
# 34:	learn: 65892.8161215	total: 152ms	remaining: 4.2s
# 35:	learn: 65639.6034031	total: 157ms	remaining: 4.2s
# 36:	learn: 65286.9900061	total: 162ms	remaining: 4.21s
# 37:	learn: 65062.2448429	total: 166ms	remaining: 4.19s
# 38:	learn: 64758.3757284	total: 170ms	remaining: 4.2s
# 39:	learn: 64563.5427027	total: 175ms	remaining: 4.2s
# 40:	learn: 64357.2436053	total: 179ms	remaining: 4.19s
# 41:	learn: 64063.1573757	total: 185ms	remaining: 4.22s
# 42:	learn: 63826.9919575	total: 191ms	remaining: 4.25s
# 43:	learn: 63611.3223287	total: 196ms	remaining: 4.25s
# 44:	learn: 63378.9108307	total: 200ms	remaining: 4.25s
# 45:	learn: 63219.0789785	total: 204ms	remaining: 4.24s
# 46:	learn: 63098.8298776	total: 208ms	remaining: 4.22s
# 47:	learn: 62836.0695863	total: 213ms	remaining: 4.22s
# 48:	learn: 62614.0133145	total: 217ms	remaining: 4.21s
# 49:	learn: 62319.3782363	total: 221ms	remaining: 4.2s
# 50:	learn: 62174.0908949	total: 225ms	remaining: 4.19s
# 51:	learn: 62002.6740315	total: 230ms	remaining: 4.2s
# 52:	learn: 61858.5463991	total: 234ms	remaining: 4.18s
# 53:	learn: 61772.5758463	total: 238ms	remaining: 4.17s
# 54:	learn: 61401.1698045	total: 242ms	remaining: 4.16s
# 55:	learn: 61225.3418517	total: 248ms	remaining: 4.18s
# 56:	learn: 60968.7910974	total: 251ms	remaining: 4.15s
# 57:	learn: 60673.2497238	total: 255ms	remaining: 4.14s
# 58:	learn: 60425.7629214	total: 259ms	remaining: 4.13s
# 59:	learn: 60300.2071092	total: 263ms	remaining: 4.13s
# 60:	learn: 60047.0007088	total: 267ms	remaining: 4.11s
# 61:	learn: 59870.1794848	total: 271ms	remaining: 4.1s
# 62:	learn: 59779.5712394	total: 276ms	remaining: 4.1s
# 63:	learn: 59559.0077680	total: 279ms	remaining: 4.08s
# 64:	learn: 59383.5963159	total: 283ms	remaining: 4.07s
# 65:	learn: 59179.4509974	total: 287ms	remaining: 4.06s
# 66:	learn: 59060.9359323	total: 292ms	remaining: 4.06s
# 67:	learn: 58965.8053957	total: 296ms	remaining: 4.06s
# 68:	learn: 58739.9355082	total: 299ms	remaining: 4.04s
# 69:	learn: 58564.0203877	total: 303ms	remaining: 4.03s
# 70:	learn: 58385.1667157	total: 308ms	remaining: 4.03s
# 71:	learn: 58235.7522368	total: 312ms	remaining: 4.02s
# 72:	learn: 58065.4102881	total: 317ms	remaining: 4.02s
# 73:	learn: 57972.0622900	total: 321ms	remaining: 4.01s
# 74:	learn: 57832.2993684	total: 325ms	remaining: 4.01s
# 75:	learn: 57636.2488686	total: 330ms	remaining: 4.01s
# 76:	learn: 57549.2086487	total: 334ms	remaining: 4s
# 77:	learn: 57467.8657557	total: 340ms	remaining: 4.01s
# 78:	learn: 57356.8645148	total: 344ms	remaining: 4.01s
# 79:	learn: 57226.3456318	total: 348ms	remaining: 4s
# 80:	learn: 57150.0603175	total: 353ms	remaining: 4s
# 81:	learn: 56953.3807073	total: 357ms	remaining: 3.99s
# 82:	learn: 56899.7963968	total: 360ms	remaining: 3.98s
# 83:	learn: 56712.9319769	total: 365ms	remaining: 3.98s
# 84:	learn: 56645.6258869	total: 369ms	remaining: 3.97s
# 85:	learn: 56547.0693869	total: 377ms	remaining: 4s
# 86:	learn: 56447.7418745	total: 382ms	remaining: 4.01s
# 87:	learn: 56389.7672604	total: 387ms	remaining: 4.01s
# 88:	learn: 56283.3287673	total: 391ms	remaining: 4s
# 89:	learn: 56206.6521726	total: 395ms	remaining: 3.99s
# 90:	learn: 56111.4785553	total: 400ms	remaining: 3.99s
# 91:	learn: 56058.0602541	total: 404ms	remaining: 3.99s
# 92:	learn: 56008.4382978	total: 408ms	remaining: 3.98s
# 93:	learn: 55863.3307246	total: 412ms	remaining: 3.97s
# 94:	learn: 55774.0048891	total: 416ms	remaining: 3.96s
# 95:	learn: 55645.6489041	total: 420ms	remaining: 3.96s
# 96:	learn: 55534.1249627	total: 424ms	remaining: 3.95s
# 97:	learn: 55474.9117755	total: 429ms	remaining: 3.95s
# 98:	learn: 55423.5818850	total: 433ms	remaining: 3.94s
# 99:	learn: 55367.7149101	total: 439ms	remaining: 3.95s
# 100:	learn: 55322.6657954	total: 443ms	remaining: 3.94s
# 101:	learn: 55255.9771276	total: 449ms	remaining: 3.95s
# 102:	learn: 55197.4864036	total: 454ms	remaining: 3.95s
# 103:	learn: 55149.0450588	total: 458ms	remaining: 3.94s
# 104:	learn: 55066.7813927	total: 462ms	remaining: 3.94s
# 105:	learn: 55003.5316014	total: 468ms	remaining: 3.95s
# 106:	learn: 54914.7779725	total: 476ms	remaining: 3.98s
# 107:	learn: 54857.1015182	total: 481ms	remaining: 3.97s
# 108:	learn: 54729.1674113	total: 485ms	remaining: 3.96s
# 109:	learn: 54690.8620186	total: 489ms	remaining: 3.96s
# 110:	learn: 54609.5961884	total: 493ms	remaining: 3.95s
# 111:	learn: 54518.0919968	total: 498ms	remaining: 3.95s
# 112:	learn: 54390.3481098	total: 503ms	remaining: 3.95s
# 113:	learn: 54325.6959777	total: 508ms	remaining: 3.95s
# 114:	learn: 54270.5884550	total: 513ms	remaining: 3.94s
# 115:	learn: 54207.6130493	total: 516ms	remaining: 3.94s
# 116:	learn: 54141.5223740	total: 521ms	remaining: 3.93s
# 117:	learn: 54064.5677168	total: 525ms	remaining: 3.92s
# 118:	learn: 54007.8608992	total: 529ms	remaining: 3.92s
# 119:	learn: 53947.8863831	total: 534ms	remaining: 3.92s
# 120:	learn: 53893.9377756	total: 538ms	remaining: 3.91s
# 121:	learn: 53827.5470845	total: 542ms	remaining: 3.9s
# 122:	learn: 53756.1940316	total: 547ms	remaining: 3.9s
# 123:	learn: 53700.1952751	total: 551ms	remaining: 3.89s
# 124:	learn: 53622.4521911	total: 555ms	remaining: 3.89s
# 125:	learn: 53551.0411040	total: 561ms	remaining: 3.89s
# 126:	learn: 53512.1116972	total: 565ms	remaining: 3.89s
# 127:	learn: 53447.7173210	total: 570ms	remaining: 3.88s
# 128:	learn: 53402.4884278	total: 574ms	remaining: 3.88s
# 129:	learn: 53356.5055609	total: 579ms	remaining: 3.87s
# 130:	learn: 53299.0016985	total: 583ms	remaining: 3.87s
# 131:	learn: 53232.7537883	total: 587ms	remaining: 3.86s
# 132:	learn: 53182.5661684	total: 592ms	remaining: 3.86s
# 133:	learn: 53125.2556199	total: 596ms	remaining: 3.85s
# 134:	learn: 53089.7626072	total: 600ms	remaining: 3.85s
# 135:	learn: 53032.6594422	total: 604ms	remaining: 3.84s
# 136:	learn: 53000.8238566	total: 608ms	remaining: 3.83s
# 137:	learn: 52962.6642850	total: 612ms	remaining: 3.82s
# 138:	learn: 52867.7888319	total: 616ms	remaining: 3.81s
# 139:	learn: 52831.0602434	total: 620ms	remaining: 3.81s
# 140:	learn: 52791.8669147	total: 625ms	remaining: 3.81s
# 141:	learn: 52739.0009517	total: 629ms	remaining: 3.8s
# 142:	learn: 52674.2508194	total: 633ms	remaining: 3.79s
# 143:	learn: 52636.6707835	total: 637ms	remaining: 3.78s
# 144:	learn: 52622.7175145	total: 641ms	remaining: 3.78s
# 145:	learn: 52584.5930452	total: 645ms	remaining: 3.77s
# 146:	learn: 52526.6949101	total: 649ms	remaining: 3.76s
# 147:	learn: 52479.3252372	total: 653ms	remaining: 3.76s
# 148:	learn: 52451.2617484	total: 656ms	remaining: 3.75s
# 149:	learn: 52428.2927450	total: 661ms	remaining: 3.74s
# 150:	learn: 52393.6593036	total: 665ms	remaining: 3.74s
# 151:	learn: 52308.9186208	total: 670ms	remaining: 3.74s
# 152:	learn: 52287.2275302	total: 674ms	remaining: 3.73s
# 153:	learn: 52249.6193668	total: 678ms	remaining: 3.72s
# 154:	learn: 52168.1384099	total: 682ms	remaining: 3.72s
# 155:	learn: 52096.5742446	total: 687ms	remaining: 3.72s
# 156:	learn: 52052.7699801	total: 692ms	remaining: 3.71s
# 157:	learn: 51983.0020766	total: 697ms	remaining: 3.72s
# 158:	learn: 51934.5031084	total: 702ms	remaining: 3.71s
# 159:	learn: 51901.9231459	total: 706ms	remaining: 3.71s
# 160:	learn: 51835.2299353	total: 710ms	remaining: 3.7s
# 161:	learn: 51794.7622051	total: 714ms	remaining: 3.69s
# 162:	learn: 51739.6333394	total: 719ms	remaining: 3.69s
# 163:	learn: 51692.5598112	total: 723ms	remaining: 3.68s
# 164:	learn: 51669.9548730	total: 727ms	remaining: 3.68s
# 165:	learn: 51633.6098475	total: 731ms	remaining: 3.67s
# 166:	learn: 51592.3694060	total: 734ms	remaining: 3.66s
# 167:	learn: 51553.5382590	total: 739ms	remaining: 3.66s
# 168:	learn: 51514.0418696	total: 745ms	remaining: 3.66s
# 169:	learn: 51452.1114618	total: 749ms	remaining: 3.66s
# 170:	learn: 51398.1271227	total: 754ms	remaining: 3.66s
# 171:	learn: 51354.6828328	total: 758ms	remaining: 3.65s
# 172:	learn: 51326.7855895	total: 762ms	remaining: 3.64s
# 173:	learn: 51286.6782244	total: 766ms	remaining: 3.64s
# 174:	learn: 51238.9234493	total: 770ms	remaining: 3.63s
# 175:	learn: 51198.0244441	total: 774ms	remaining: 3.63s
# 176:	learn: 51161.8006306	total: 779ms	remaining: 3.62s
# 177:	learn: 51121.0113835	total: 783ms	remaining: 3.62s
# 178:	learn: 51093.6588645	total: 787ms	remaining: 3.61s
# 179:	learn: 51054.8071789	total: 791ms	remaining: 3.6s
# 180:	learn: 51027.2659936	total: 795ms	remaining: 3.6s
# 181:	learn: 50999.9812058	total: 798ms	remaining: 3.59s
# 182:	learn: 50951.1824535	total: 803ms	remaining: 3.59s
# 183:	learn: 50931.2090734	total: 808ms	remaining: 3.58s
# 184:	learn: 50893.5200644	total: 812ms	remaining: 3.58s
# 185:	learn: 50866.1673989	total: 816ms	remaining: 3.57s
# 186:	learn: 50841.6344466	total: 820ms	remaining: 3.57s
# 187:	learn: 50797.2764380	total: 825ms	remaining: 3.56s
# 188:	learn: 50776.9871671	total: 829ms	remaining: 3.56s
# 189:	learn: 50730.7513014	total: 833ms	remaining: 3.55s
# 190:	learn: 50698.5495363	total: 837ms	remaining: 3.54s
# 191:	learn: 50678.9410723	total: 840ms	remaining: 3.54s
# 192:	learn: 50650.8267843	total: 846ms	remaining: 3.54s
# 193:	learn: 50614.3191147	total: 850ms	remaining: 3.53s
# 194:	learn: 50570.7971835	total: 855ms	remaining: 3.53s
# 195:	learn: 50511.7652228	total: 859ms	remaining: 3.52s
# 196:	learn: 50463.8479658	total: 863ms	remaining: 3.52s
# 197:	learn: 50429.9223712	total: 867ms	remaining: 3.51s
# 198:	learn: 50401.4638749	total: 871ms	remaining: 3.51s
# 199:	learn: 50370.0112506	total: 875ms	remaining: 3.5s
# 200:	learn: 50328.7734698	total: 880ms	remaining: 3.5s
# 201:	learn: 50300.8447809	total: 884ms	remaining: 3.49s
# 202:	learn: 50261.5048500	total: 890ms	remaining: 3.49s
# 203:	learn: 50242.1034615	total: 894ms	remaining: 3.49s
# 204:	learn: 50210.0042702	total: 898ms	remaining: 3.48s
# 205:	learn: 50181.3718251	total: 901ms	remaining: 3.47s
# 206:	learn: 50143.3130952	total: 907ms	remaining: 3.48s
# 207:	learn: 50117.8965892	total: 912ms	remaining: 3.47s
# 208:	learn: 50094.0650354	total: 916ms	remaining: 3.46s
# 209:	learn: 50047.9049046	total: 920ms	remaining: 3.46s
# 210:	learn: 50030.5986690	total: 924ms	remaining: 3.45s
# 211:	learn: 49998.7404255	total: 928ms	remaining: 3.45s
# 212:	learn: 49983.0835091	total: 934ms	remaining: 3.45s
# 213:	learn: 49948.3542732	total: 938ms	remaining: 3.44s
# 214:	learn: 49916.1832398	total: 942ms	remaining: 3.44s
# 215:	learn: 49879.6069387	total: 946ms	remaining: 3.43s
# 216:	learn: 49856.0210058	total: 950ms	remaining: 3.43s
# 217:	learn: 49821.5996227	total: 954ms	remaining: 3.42s
# 218:	learn: 49800.9993512	total: 958ms	remaining: 3.42s
# 219:	learn: 49769.1759357	total: 962ms	remaining: 3.41s
# 220:	learn: 49715.0113367	total: 967ms	remaining: 3.41s
# 221:	learn: 49695.2019339	total: 970ms	remaining: 3.4s
# 222:	learn: 49649.4343867	total: 974ms	remaining: 3.39s
# 223:	learn: 49628.9115835	total: 977ms	remaining: 3.38s
# 224:	learn: 49611.1356627	total: 981ms	remaining: 3.38s
# 225:	learn: 49580.6345386	total: 985ms	remaining: 3.37s
# 226:	learn: 49548.3745849	total: 989ms	remaining: 3.37s
# 227:	learn: 49511.1553851	total: 993ms	remaining: 3.36s
# 228:	learn: 49464.7218731	total: 997ms	remaining: 3.36s
# 229:	learn: 49427.9804456	total: 1s	remaining: 3.36s
# 230:	learn: 49400.2263913	total: 1.01s	remaining: 3.35s
# 231:	learn: 49373.4275762	total: 1.01s	remaining: 3.35s
# 232:	learn: 49346.8012234	total: 1.01s	remaining: 3.34s
# 233:	learn: 49320.5970317	total: 1.02s	remaining: 3.33s
# 234:	learn: 49287.7925634	total: 1.02s	remaining: 3.33s
# 235:	learn: 49258.2806879	total: 1.03s	remaining: 3.33s
# 236:	learn: 49214.4931192	total: 1.03s	remaining: 3.32s
# 237:	learn: 49190.2890209	total: 1.03s	remaining: 3.32s
# 238:	learn: 49161.9659785	total: 1.04s	remaining: 3.31s
# 239:	learn: 49131.0630641	total: 1.04s	remaining: 3.31s
# 240:	learn: 49111.6799536	total: 1.05s	remaining: 3.3s
# 241:	learn: 49083.1143806	total: 1.05s	remaining: 3.29s
# 242:	learn: 49050.6154795	total: 1.06s	remaining: 3.29s
# 243:	learn: 49014.4883638	total: 1.06s	remaining: 3.29s
# 244:	learn: 48987.6177799	total: 1.06s	remaining: 3.28s
# 245:	learn: 48966.8389350	total: 1.07s	remaining: 3.28s
# 246:	learn: 48948.0876232	total: 1.07s	remaining: 3.27s
# 247:	learn: 48917.2785128	total: 1.08s	remaining: 3.27s
# 248:	learn: 48894.7541990	total: 1.08s	remaining: 3.26s
# 249:	learn: 48883.6454135	total: 1.08s	remaining: 3.25s
# 250:	learn: 48847.2154872	total: 1.09s	remaining: 3.25s
# 251:	learn: 48820.4606158	total: 1.09s	remaining: 3.25s
# 252:	learn: 48790.6583997	total: 1.1s	remaining: 3.24s
# 253:	learn: 48762.9554188	total: 1.1s	remaining: 3.23s
# 254:	learn: 48745.7960738	total: 1.1s	remaining: 3.23s
# 255:	learn: 48721.9502717	total: 1.11s	remaining: 3.23s
# 256:	learn: 48697.4669340	total: 1.11s	remaining: 3.22s
# 257:	learn: 48677.4879774	total: 1.12s	remaining: 3.22s
# 258:	learn: 48662.1831175	total: 1.12s	remaining: 3.21s
# 259:	learn: 48645.9218069	total: 1.13s	remaining: 3.21s
# 260:	learn: 48628.8291296	total: 1.13s	remaining: 3.2s
# 261:	learn: 48602.4347766	total: 1.14s	remaining: 3.2s
# 262:	learn: 48587.2525948	total: 1.14s	remaining: 3.19s
# 263:	learn: 48573.7036921	total: 1.14s	remaining: 3.19s
# 264:	learn: 48557.7465041	total: 1.15s	remaining: 3.2s
# 265:	learn: 48529.3280004	total: 1.16s	remaining: 3.19s
# 266:	learn: 48497.1479937	total: 1.16s	remaining: 3.18s
# 267:	learn: 48470.7542841	total: 1.16s	remaining: 3.18s
# 268:	learn: 48450.9842485	total: 1.17s	remaining: 3.17s
# 269:	learn: 48425.3598502	total: 1.17s	remaining: 3.17s
# 270:	learn: 48400.4328536	total: 1.18s	remaining: 3.16s
# 271:	learn: 48378.7761879	total: 1.18s	remaining: 3.16s
# 272:	learn: 48366.5426098	total: 1.18s	remaining: 3.15s
# 273:	learn: 48347.1718946	total: 1.19s	remaining: 3.15s
# 274:	learn: 48324.1961214	total: 1.19s	remaining: 3.14s
# 275:	learn: 48295.7882026	total: 1.19s	remaining: 3.13s
# 276:	learn: 48271.0088978	total: 1.2s	remaining: 3.13s
# 277:	learn: 48248.9036619	total: 1.2s	remaining: 3.13s
# 278:	learn: 48227.0432256	total: 1.21s	remaining: 3.12s
# 279:	learn: 48198.6083210	total: 1.21s	remaining: 3.12s
# 280:	learn: 48182.2980620	total: 1.22s	remaining: 3.11s
# 281:	learn: 48162.5779535	total: 1.22s	remaining: 3.11s
# 282:	learn: 48141.4574407	total: 1.23s	remaining: 3.1s
# 283:	learn: 48115.2739049	total: 1.23s	remaining: 3.1s
# 284:	learn: 48091.6175170	total: 1.23s	remaining: 3.1s
# 285:	learn: 48070.4977960	total: 1.24s	remaining: 3.09s
# 286:	learn: 48048.5492094	total: 1.24s	remaining: 3.09s
# 287:	learn: 48020.5148266	total: 1.25s	remaining: 3.08s
# 288:	learn: 47987.3437205	total: 1.25s	remaining: 3.08s
# 289:	learn: 47976.4001727	total: 1.25s	remaining: 3.07s
# 290:	learn: 47949.4531918	total: 1.26s	remaining: 3.07s
# 291:	learn: 47930.5490534	total: 1.26s	remaining: 3.06s
# 292:	learn: 47915.1496342	total: 1.27s	remaining: 3.06s
# 293:	learn: 47905.6692450	total: 1.27s	remaining: 3.06s
# 294:	learn: 47890.0348511	total: 1.28s	remaining: 3.05s
# 295:	learn: 47874.9713279	total: 1.28s	remaining: 3.04s
# 296:	learn: 47850.1483781	total: 1.28s	remaining: 3.04s
# 297:	learn: 47832.6396272	total: 1.29s	remaining: 3.04s
# 298:	learn: 47817.0467299	total: 1.29s	remaining: 3.03s
# 299:	learn: 47800.0371741	total: 1.3s	remaining: 3.03s
# 300:	learn: 47787.8826148	total: 1.31s	remaining: 3.03s
# 301:	learn: 47768.6953427	total: 1.31s	remaining: 3.03s
# 302:	learn: 47744.9120766	total: 1.32s	remaining: 3.03s
# 303:	learn: 47722.2831018	total: 1.32s	remaining: 3.03s
# 304:	learn: 47704.2381127	total: 1.32s	remaining: 3.02s
# 305:	learn: 47679.6603646	total: 1.33s	remaining: 3.02s
# 306:	learn: 47665.5955111	total: 1.33s	remaining: 3.01s
# 307:	learn: 47651.9712610	total: 1.34s	remaining: 3s
# 308:	learn: 47636.5439545	total: 1.34s	remaining: 3s
# 309:	learn: 47611.8816438	total: 1.34s	remaining: 3s
# 310:	learn: 47590.1810449	total: 1.35s	remaining: 2.99s
# 311:	learn: 47567.5078835	total: 1.35s	remaining: 2.98s
# 312:	learn: 47550.5949032	total: 1.36s	remaining: 2.98s
# 313:	learn: 47538.9403728	total: 1.36s	remaining: 2.98s
# 314:	learn: 47515.7204027	total: 1.37s	remaining: 2.97s
# 315:	learn: 47507.1148988	total: 1.37s	remaining: 2.97s
# 316:	learn: 47483.6106155	total: 1.38s	remaining: 2.96s
# 317:	learn: 47461.2162815	total: 1.38s	remaining: 2.96s
# 318:	learn: 47437.8848294	total: 1.38s	remaining: 2.96s
# 319:	learn: 47424.4191344	total: 1.39s	remaining: 2.95s
# 320:	learn: 47402.7862726	total: 1.39s	remaining: 2.95s
# 321:	learn: 47383.2000280	total: 1.4s	remaining: 2.94s
# 322:	learn: 47361.8715683	total: 1.4s	remaining: 2.94s
# 323:	learn: 47349.3100638	total: 1.41s	remaining: 2.94s
# 324:	learn: 47324.9059084	total: 1.41s	remaining: 2.93s
# 325:	learn: 47303.9590356	total: 1.42s	remaining: 2.93s
# 326:	learn: 47293.9686582	total: 1.42s	remaining: 2.92s
# 327:	learn: 47283.7607542	total: 1.42s	remaining: 2.92s
# 328:	learn: 47273.0923952	total: 1.43s	remaining: 2.91s
# 329:	learn: 47260.8730715	total: 1.43s	remaining: 2.91s
# 330:	learn: 47237.1194131	total: 1.44s	remaining: 2.9s
# 331:	learn: 47224.7958568	total: 1.44s	remaining: 2.89s
# 332:	learn: 47206.3261712	total: 1.44s	remaining: 2.89s
# 333:	learn: 47187.2100459	total: 1.45s	remaining: 2.88s
# 334:	learn: 47170.0812667	total: 1.45s	remaining: 2.88s
# 335:	learn: 47158.5060314	total: 1.45s	remaining: 2.87s
# 336:	learn: 47142.4205119	total: 1.46s	remaining: 2.87s
# 337:	learn: 47129.8886221	total: 1.46s	remaining: 2.87s
# 338:	learn: 47112.6462944	total: 1.47s	remaining: 2.86s
# 339:	learn: 47097.7708731	total: 1.47s	remaining: 2.86s
# 340:	learn: 47078.1391493	total: 1.48s	remaining: 2.85s
# 341:	learn: 47064.9266108	total: 1.48s	remaining: 2.85s
# 342:	learn: 47040.8733759	total: 1.49s	remaining: 2.85s
# 343:	learn: 47022.2815874	total: 1.49s	remaining: 2.85s
# 344:	learn: 47004.9462049	total: 1.5s	remaining: 2.85s
# 345:	learn: 46989.8615391	total: 1.5s	remaining: 2.84s
# 346:	learn: 46974.3075861	total: 1.51s	remaining: 2.84s
# 347:	learn: 46958.9587992	total: 1.51s	remaining: 2.83s
# 348:	learn: 46949.1411528	total: 1.51s	remaining: 2.83s
# 349:	learn: 46924.1700987	total: 1.52s	remaining: 2.82s
# 350:	learn: 46913.4621435	total: 1.52s	remaining: 2.81s
# 351:	learn: 46893.9835294	total: 1.53s	remaining: 2.81s
# 352:	learn: 46873.5488451	total: 1.53s	remaining: 2.8s
# 353:	learn: 46848.1561617	total: 1.53s	remaining: 2.8s
# 354:	learn: 46833.6892449	total: 1.54s	remaining: 2.79s
# 355:	learn: 46816.6484846	total: 1.54s	remaining: 2.79s
# 356:	learn: 46800.7044411	total: 1.55s	remaining: 2.79s
# 357:	learn: 46788.7200992	total: 1.55s	remaining: 2.79s
# 358:	learn: 46775.5493846	total: 1.56s	remaining: 2.78s
# 359:	learn: 46760.3107475	total: 1.56s	remaining: 2.78s
# 360:	learn: 46750.1507380	total: 1.57s	remaining: 2.77s
# 361:	learn: 46738.5030824	total: 1.58s	remaining: 2.78s
# 362:	learn: 46723.2595279	total: 1.58s	remaining: 2.77s
# 363:	learn: 46694.3746608	total: 1.59s	remaining: 2.77s
# 364:	learn: 46674.0781102	total: 1.59s	remaining: 2.77s
# 365:	learn: 46660.7478495	total: 1.59s	remaining: 2.76s
# 366:	learn: 46641.3709261	total: 1.6s	remaining: 2.75s
# 367:	learn: 46628.5764457	total: 1.6s	remaining: 2.75s
# 368:	learn: 46608.0609736	total: 1.61s	remaining: 2.75s
# 369:	learn: 46588.8661513	total: 1.61s	remaining: 2.74s
# 370:	learn: 46580.5759759	total: 1.61s	remaining: 2.74s
# 371:	learn: 46572.0380264	total: 1.62s	remaining: 2.73s
# 372:	learn: 46558.1253790	total: 1.62s	remaining: 2.73s
# 373:	learn: 46545.6064771	total: 1.63s	remaining: 2.72s
# 374:	learn: 46530.9244727	total: 1.63s	remaining: 2.72s
# 375:	learn: 46515.8757640	total: 1.64s	remaining: 2.71s
# 376:	learn: 46499.1328260	total: 1.64s	remaining: 2.71s
# 377:	learn: 46487.9688193	total: 1.64s	remaining: 2.7s
# 378:	learn: 46461.8422563	total: 1.65s	remaining: 2.7s
# 379:	learn: 46452.1795548	total: 1.65s	remaining: 2.69s
# 380:	learn: 46437.4647428	total: 1.66s	remaining: 2.69s
# 381:	learn: 46430.9536793	total: 1.66s	remaining: 2.69s
# 382:	learn: 46419.5067525	total: 1.66s	remaining: 2.68s
# 383:	learn: 46406.9940475	total: 1.67s	remaining: 2.68s
# 384:	learn: 46391.9315401	total: 1.67s	remaining: 2.67s
# 385:	learn: 46380.2647850	total: 1.68s	remaining: 2.67s
# 386:	learn: 46365.7265528	total: 1.68s	remaining: 2.66s
# 387:	learn: 46348.4638911	total: 1.69s	remaining: 2.66s
# 388:	learn: 46336.3890862	total: 1.69s	remaining: 2.66s
# 389:	learn: 46325.1123357	total: 1.7s	remaining: 2.65s
# 390:	learn: 46308.7952458	total: 1.7s	remaining: 2.65s
# 391:	learn: 46292.7588596	total: 1.7s	remaining: 2.64s
# 392:	learn: 46282.5632771	total: 1.71s	remaining: 2.64s
# 393:	learn: 46274.8517015	total: 1.71s	remaining: 2.63s
# 394:	learn: 46262.8022363	total: 1.72s	remaining: 2.63s
# 395:	learn: 46254.7070195	total: 1.72s	remaining: 2.62s
# 396:	learn: 46245.8753706	total: 1.72s	remaining: 2.62s
# 397:	learn: 46240.2666620	total: 1.73s	remaining: 2.61s
# 398:	learn: 46229.3796126	total: 1.73s	remaining: 2.61s
# 399:	learn: 46206.2137510	total: 1.73s	remaining: 2.6s
# 400:	learn: 46192.5915787	total: 1.74s	remaining: 2.6s
# 401:	learn: 46169.1374990	total: 1.74s	remaining: 2.59s
# 402:	learn: 46152.0722664	total: 1.75s	remaining: 2.59s
# 403:	learn: 46134.8990185	total: 1.75s	remaining: 2.58s
# 404:	learn: 46119.0769126	total: 1.76s	remaining: 2.58s
# 405:	learn: 46099.8940905	total: 1.76s	remaining: 2.58s
# 406:	learn: 46085.9726058	total: 1.76s	remaining: 2.57s
# 407:	learn: 46064.0272910	total: 1.77s	remaining: 2.57s
# 408:	learn: 46048.0701498	total: 1.77s	remaining: 2.56s
# 409:	learn: 46029.7772626	total: 1.78s	remaining: 2.56s
# 410:	learn: 46018.6485965	total: 1.78s	remaining: 2.56s
# 411:	learn: 46003.4712997	total: 1.79s	remaining: 2.55s
# 412:	learn: 45981.1529230	total: 1.79s	remaining: 2.55s
# 413:	learn: 45962.2032141	total: 1.8s	remaining: 2.54s
# 414:	learn: 45952.3382204	total: 1.8s	remaining: 2.54s
# 415:	learn: 45936.2684520	total: 1.81s	remaining: 2.54s
# 416:	learn: 45924.6235675	total: 1.81s	remaining: 2.54s
# 417:	learn: 45915.2230564	total: 1.82s	remaining: 2.53s
# 418:	learn: 45901.3302975	total: 1.82s	remaining: 2.53s
# 419:	learn: 45890.8499931	total: 1.83s	remaining: 2.53s
# 420:	learn: 45877.2536587	total: 1.83s	remaining: 2.52s
# 421:	learn: 45866.6886119	total: 1.84s	remaining: 2.52s
# 422:	learn: 45858.0629779	total: 1.85s	remaining: 2.52s
# 423:	learn: 45836.9983459	total: 1.85s	remaining: 2.52s
# 424:	learn: 45825.9917372	total: 1.86s	remaining: 2.52s
# 425:	learn: 45819.5328029	total: 1.86s	remaining: 2.51s
# 426:	learn: 45808.8682345	total: 1.87s	remaining: 2.51s
# 427:	learn: 45795.9828049	total: 1.87s	remaining: 2.5s
# 428:	learn: 45787.1199612	total: 1.88s	remaining: 2.5s
# 429:	learn: 45761.9980458	total: 1.89s	remaining: 2.5s
# 430:	learn: 45751.8262302	total: 1.89s	remaining: 2.5s
# 431:	learn: 45742.2772019	total: 1.9s	remaining: 2.49s
# 432:	learn: 45733.9295195	total: 1.9s	remaining: 2.49s
# 433:	learn: 45727.7214391	total: 1.91s	remaining: 2.49s
# 434:	learn: 45714.7568436	total: 1.92s	remaining: 2.49s
# 435:	learn: 45709.5419930	total: 1.92s	remaining: 2.48s
# 436:	learn: 45698.6545507	total: 1.92s	remaining: 2.48s
# 437:	learn: 45683.8034439	total: 1.93s	remaining: 2.48s
# 438:	learn: 45669.4310899	total: 1.93s	remaining: 2.47s
# 439:	learn: 45648.9241820	total: 1.94s	remaining: 2.47s
# 440:	learn: 45633.2887230	total: 1.94s	remaining: 2.46s
# 441:	learn: 45627.5688778	total: 1.95s	remaining: 2.46s
# 442:	learn: 45614.1208396	total: 1.95s	remaining: 2.46s
# 443:	learn: 45602.6450162	total: 1.96s	remaining: 2.45s
# 444:	learn: 45592.8512730	total: 1.96s	remaining: 2.45s
# 445:	learn: 45579.2036586	total: 1.97s	remaining: 2.45s
# 446:	learn: 45566.5727543	total: 1.97s	remaining: 2.44s
# 447:	learn: 45558.3064626	total: 1.98s	remaining: 2.44s
# 448:	learn: 45547.6453475	total: 1.99s	remaining: 2.44s
# 449:	learn: 45540.9471439	total: 1.99s	remaining: 2.43s
# 450:	learn: 45527.8921565	total: 2s	remaining: 2.43s
# 451:	learn: 45511.8726786	total: 2s	remaining: 2.42s
# 452:	learn: 45503.7661883	total: 2s	remaining: 2.42s
# 453:	learn: 45494.4081916	total: 2.01s	remaining: 2.42s
# 454:	learn: 45484.5249724	total: 2.01s	remaining: 2.41s
# 455:	learn: 45468.5706107	total: 2.02s	remaining: 2.41s
# 456:	learn: 45465.1884881	total: 2.02s	remaining: 2.4s
# 457:	learn: 45455.0702737	total: 2.03s	remaining: 2.4s
# 458:	learn: 45447.5868890	total: 2.04s	remaining: 2.4s
# 459:	learn: 45438.1131009	total: 2.04s	remaining: 2.4s
# 460:	learn: 45434.4745188	total: 2.05s	remaining: 2.4s
# 461:	learn: 45420.1372032	total: 2.06s	remaining: 2.4s
# 462:	learn: 45410.1506798	total: 2.06s	remaining: 2.39s
# 463:	learn: 45396.1439133	total: 2.07s	remaining: 2.39s
# 464:	learn: 45380.6146708	total: 2.08s	remaining: 2.39s
# 465:	learn: 45374.4943150	total: 2.08s	remaining: 2.38s
# 466:	learn: 45355.9713750	total: 2.09s	remaining: 2.38s
# 467:	learn: 45347.0395879	total: 2.09s	remaining: 2.38s
# 468:	learn: 45338.9902592	total: 2.1s	remaining: 2.37s
# 469:	learn: 45325.5902752	total: 2.1s	remaining: 2.37s
# 470:	learn: 45317.5766034	total: 2.1s	remaining: 2.36s
# 471:	learn: 45302.0327824	total: 2.11s	remaining: 2.36s
# 472:	learn: 45280.8777332	total: 2.12s	remaining: 2.36s
# 473:	learn: 45275.9665052	total: 2.12s	remaining: 2.35s
# 474:	learn: 45269.0734791	total: 2.13s	remaining: 2.35s
# 475:	learn: 45262.3544323	total: 2.13s	remaining: 2.35s
# 476:	learn: 45242.1886261	total: 2.13s	remaining: 2.34s
# 477:	learn: 45230.4956858	total: 2.14s	remaining: 2.33s
# 478:	learn: 45220.1352968	total: 2.14s	remaining: 2.33s
# 479:	learn: 45207.2639361	total: 2.15s	remaining: 2.33s
# 480:	learn: 45188.6633037	total: 2.15s	remaining: 2.32s
# 481:	learn: 45179.4797092	total: 2.16s	remaining: 2.32s
# 482:	learn: 45166.2238301	total: 2.16s	remaining: 2.32s
# 483:	learn: 45147.4706007	total: 2.17s	remaining: 2.31s
# 484:	learn: 45142.6528333	total: 2.17s	remaining: 2.31s
# 485:	learn: 45137.5788938	total: 2.18s	remaining: 2.3s
# 486:	learn: 45129.3542029	total: 2.18s	remaining: 2.3s
# 487:	learn: 45119.7247012	total: 2.19s	remaining: 2.29s
# 488:	learn: 45108.3388224	total: 2.19s	remaining: 2.29s
# 489:	learn: 45091.5848237	total: 2.19s	remaining: 2.28s
# 490:	learn: 45075.3242112	total: 2.2s	remaining: 2.28s
# 491:	learn: 45064.2436403	total: 2.21s	remaining: 2.28s
# 492:	learn: 45051.2203897	total: 2.21s	remaining: 2.27s
# 493:	learn: 45029.7669432	total: 2.21s	remaining: 2.27s
# 494:	learn: 45019.0294364	total: 2.22s	remaining: 2.27s
# 495:	learn: 45014.7726350	total: 2.23s	remaining: 2.27s
# 496:	learn: 45011.8282108	total: 2.23s	remaining: 2.26s
# 497:	learn: 44989.7526826	total: 2.24s	remaining: 2.26s
# 498:	learn: 44982.4920867	total: 2.25s	remaining: 2.26s
# 499:	learn: 44975.9698324	total: 2.25s	remaining: 2.25s
# 500:	learn: 44969.6697917	total: 2.26s	remaining: 2.25s
# 501:	learn: 44959.4666397	total: 2.27s	remaining: 2.25s
# 502:	learn: 44944.6727211	total: 2.28s	remaining: 2.25s
# 503:	learn: 44930.6878190	total: 2.28s	remaining: 2.24s
# 504:	learn: 44912.2383031	total: 2.29s	remaining: 2.25s
# 505:	learn: 44900.8321505	total: 2.3s	remaining: 2.24s
# 506:	learn: 44888.7183961	total: 2.31s	remaining: 2.25s
# 507:	learn: 44878.9131498	total: 2.32s	remaining: 2.25s
# 508:	learn: 44874.1410226	total: 2.33s	remaining: 2.25s
# 509:	learn: 44869.7450903	total: 2.34s	remaining: 2.25s
# 510:	learn: 44862.3051460	total: 2.35s	remaining: 2.24s
# 511:	learn: 44843.2458851	total: 2.35s	remaining: 2.24s
# 512:	learn: 44832.4613314	total: 2.36s	remaining: 2.24s
# 513:	learn: 44815.1712286	total: 2.36s	remaining: 2.23s
# 514:	learn: 44808.3750313	total: 2.37s	remaining: 2.23s
# 515:	learn: 44797.3107162	total: 2.38s	remaining: 2.23s
# 516:	learn: 44787.8625551	total: 2.38s	remaining: 2.23s
# 517:	learn: 44766.2101565	total: 2.39s	remaining: 2.22s
# 518:	learn: 44761.4984072	total: 2.4s	remaining: 2.22s
# 519:	learn: 44756.2060674	total: 2.4s	remaining: 2.22s
# 520:	learn: 44741.6308887	total: 2.41s	remaining: 2.22s
# 521:	learn: 44731.5443849	total: 2.42s	remaining: 2.21s
# 522:	learn: 44723.8787111	total: 2.42s	remaining: 2.21s
# 523:	learn: 44714.1936452	total: 2.43s	remaining: 2.21s
# 524:	learn: 44706.5196450	total: 2.43s	remaining: 2.2s
# 525:	learn: 44693.6373101	total: 2.44s	remaining: 2.2s
# 526:	learn: 44675.0549833	total: 2.45s	remaining: 2.19s
# 527:	learn: 44665.6358889	total: 2.45s	remaining: 2.19s
# 528:	learn: 44651.9682530	total: 2.47s	remaining: 2.2s
# 529:	learn: 44634.5150490	total: 2.49s	remaining: 2.21s
# 530:	learn: 44624.0161640	total: 2.51s	remaining: 2.21s
# 531:	learn: 44614.1779261	total: 2.52s	remaining: 2.22s
# 532:	learn: 44611.4274837	total: 2.55s	remaining: 2.23s
# 533:	learn: 44594.6273408	total: 2.56s	remaining: 2.24s
# 534:	learn: 44584.6583940	total: 2.59s	remaining: 2.25s
# 535:	learn: 44576.2238484	total: 2.6s	remaining: 2.25s
# 536:	learn: 44563.3204644	total: 2.61s	remaining: 2.25s
# 537:	learn: 44553.7723411	total: 2.62s	remaining: 2.25s
# 538:	learn: 44543.5943860	total: 2.65s	remaining: 2.27s
# 539:	learn: 44539.4824106	total: 2.66s	remaining: 2.27s
# 540:	learn: 44529.8907351	total: 2.67s	remaining: 2.27s
# 541:	learn: 44517.8636873	total: 2.69s	remaining: 2.27s
# 542:	learn: 44504.5623805	total: 2.71s	remaining: 2.28s
# 543:	learn: 44500.7129677	total: 2.71s	remaining: 2.27s
# 544:	learn: 44489.1538942	total: 2.72s	remaining: 2.27s
# 545:	learn: 44481.2352819	total: 2.72s	remaining: 2.27s
# 546:	learn: 44475.3782545	total: 2.73s	remaining: 2.26s
# 547:	learn: 44469.7336026	total: 2.74s	remaining: 2.26s
# 548:	learn: 44461.1304700	total: 2.75s	remaining: 2.26s
# 549:	learn: 44445.7026249	total: 2.75s	remaining: 2.25s
# 550:	learn: 44441.1967905	total: 2.76s	remaining: 2.25s
# 551:	learn: 44428.0772568	total: 2.77s	remaining: 2.25s
# 552:	learn: 44417.5491535	total: 2.77s	remaining: 2.24s
# 553:	learn: 44409.2413072	total: 2.78s	remaining: 2.24s
# 554:	learn: 44398.4868981	total: 2.78s	remaining: 2.23s
# 555:	learn: 44381.5101054	total: 2.79s	remaining: 2.23s
# 556:	learn: 44376.9329900	total: 2.79s	remaining: 2.22s
# 557:	learn: 44360.6077133	total: 2.8s	remaining: 2.21s
# 558:	learn: 44354.6947081	total: 2.8s	remaining: 2.21s
# 559:	learn: 44350.4859026	total: 2.81s	remaining: 2.2s
# 560:	learn: 44334.4724577	total: 2.81s	remaining: 2.2s
# 561:	learn: 44327.8153595	total: 2.82s	remaining: 2.19s
# 562:	learn: 44323.8983329	total: 2.82s	remaining: 2.19s
# 563:	learn: 44307.8309745	total: 2.83s	remaining: 2.19s
# 564:	learn: 44303.7256022	total: 2.83s	remaining: 2.18s
# 565:	learn: 44295.1261533	total: 2.84s	remaining: 2.17s
# 566:	learn: 44286.5828813	total: 2.84s	remaining: 2.17s
# 567:	learn: 44269.4484034	total: 2.85s	remaining: 2.17s
# 568:	learn: 44257.7502048	total: 2.85s	remaining: 2.16s
# 569:	learn: 44246.0086949	total: 2.86s	remaining: 2.15s
# 570:	learn: 44242.1964564	total: 2.86s	remaining: 2.15s
# 571:	learn: 44229.0440037	total: 2.87s	remaining: 2.14s
# 572:	learn: 44219.3261395	total: 2.87s	remaining: 2.14s
# 573:	learn: 44213.7334146	total: 2.87s	remaining: 2.13s
# 574:	learn: 44205.5350192	total: 2.88s	remaining: 2.13s
# 575:	learn: 44191.8446524	total: 2.88s	remaining: 2.12s
# 576:	learn: 44184.6357645	total: 2.89s	remaining: 2.12s
# 577:	learn: 44174.3244464	total: 2.89s	remaining: 2.11s
# 578:	learn: 44165.4539702	total: 2.9s	remaining: 2.11s
# 579:	learn: 44156.7163540	total: 2.9s	remaining: 2.1s
# 580:	learn: 44144.8070031	total: 2.91s	remaining: 2.1s
# 581:	learn: 44133.9372914	total: 2.91s	remaining: 2.09s
# 582:	learn: 44122.2905640	total: 2.92s	remaining: 2.09s
# 583:	learn: 44116.0046063	total: 2.92s	remaining: 2.08s
# 584:	learn: 44105.1448271	total: 2.93s	remaining: 2.08s
# 585:	learn: 44096.2053841	total: 2.93s	remaining: 2.07s
# 586:	learn: 44086.5597719	total: 2.94s	remaining: 2.07s
# 587:	learn: 44079.5943937	total: 2.95s	remaining: 2.06s
# 588:	learn: 44067.3574201	total: 2.95s	remaining: 2.06s
# 589:	learn: 44056.0085843	total: 2.96s	remaining: 2.05s
# 590:	learn: 44050.3014928	total: 2.96s	remaining: 2.05s
# 591:	learn: 44035.8049746	total: 2.97s	remaining: 2.04s
# 592:	learn: 44022.4131251	total: 2.97s	remaining: 2.04s
# 593:	learn: 44013.6596245	total: 2.98s	remaining: 2.03s
# 594:	learn: 44004.7809712	total: 2.98s	remaining: 2.03s
# 595:	learn: 43999.1630346	total: 2.99s	remaining: 2.02s
# 596:	learn: 43989.2482352	total: 2.99s	remaining: 2.02s
# 597:	learn: 43979.1288715	total: 3s	remaining: 2.01s
# 598:	learn: 43967.8725764	total: 3s	remaining: 2.01s
# 599:	learn: 43958.7162593	total: 3.01s	remaining: 2.01s
# 600:	learn: 43955.0345182	total: 3.02s	remaining: 2s
# 601:	learn: 43944.8536733	total: 3.02s	remaining: 2s
# 602:	learn: 43933.6409233	total: 3.02s	remaining: 1.99s
# 603:	learn: 43918.1324131	total: 3.03s	remaining: 1.99s
# 604:	learn: 43912.4696343	total: 3.03s	remaining: 1.98s
# 605:	learn: 43897.1499187	total: 3.04s	remaining: 1.98s
# 606:	learn: 43884.5739314	total: 3.04s	remaining: 1.97s
# 607:	learn: 43880.0641598	total: 3.05s	remaining: 1.97s
# 608:	learn: 43868.8970597	total: 3.05s	remaining: 1.96s
# 609:	learn: 43859.3089865	total: 3.06s	remaining: 1.96s
# 610:	learn: 43848.0192923	total: 3.06s	remaining: 1.95s
# 611:	learn: 43838.2962293	total: 3.07s	remaining: 1.95s
# 612:	learn: 43832.6193956	total: 3.07s	remaining: 1.94s
# 613:	learn: 43821.5061353	total: 3.08s	remaining: 1.94s
# 614:	learn: 43809.0075291	total: 3.08s	remaining: 1.93s
# 615:	learn: 43803.6676413	total: 3.09s	remaining: 1.93s
# 616:	learn: 43796.2419490	total: 3.1s	remaining: 1.92s
# 617:	learn: 43790.1564653	total: 3.1s	remaining: 1.92s
# 618:	learn: 43784.0719100	total: 3.11s	remaining: 1.91s
# 619:	learn: 43778.8473275	total: 3.11s	remaining: 1.91s
# 620:	learn: 43771.0015880	total: 3.12s	remaining: 1.9s
# 621:	learn: 43758.3246662	total: 3.12s	remaining: 1.9s
# 622:	learn: 43752.7097284	total: 3.13s	remaining: 1.89s
# 623:	learn: 43741.0668140	total: 3.13s	remaining: 1.89s
# 624:	learn: 43720.5947840	total: 3.14s	remaining: 1.88s
# 625:	learn: 43714.2389043	total: 3.14s	remaining: 1.88s
# 626:	learn: 43704.5071497	total: 3.15s	remaining: 1.87s
# 627:	learn: 43696.5047106	total: 3.15s	remaining: 1.87s
# 628:	learn: 43695.0500091	total: 3.16s	remaining: 1.86s
# 629:	learn: 43681.7402897	total: 3.16s	remaining: 1.86s
# 630:	learn: 43677.5426871	total: 3.17s	remaining: 1.85s
# 631:	learn: 43662.1375572	total: 3.17s	remaining: 1.85s
# 632:	learn: 43657.4386145	total: 3.18s	remaining: 1.84s
# 633:	learn: 43646.5295422	total: 3.18s	remaining: 1.84s
# 634:	learn: 43634.5046643	total: 3.19s	remaining: 1.83s
# 635:	learn: 43628.0377393	total: 3.19s	remaining: 1.83s
# 636:	learn: 43616.1222952	total: 3.2s	remaining: 1.82s
# 637:	learn: 43608.1911535	total: 3.2s	remaining: 1.82s
# 638:	learn: 43599.5696921	total: 3.21s	remaining: 1.81s
# 639:	learn: 43592.9946413	total: 3.21s	remaining: 1.8s
# 640:	learn: 43590.0296185	total: 3.21s	remaining: 1.8s
# 641:	learn: 43584.6691861	total: 3.22s	remaining: 1.8s
# 642:	learn: 43580.8341273	total: 3.23s	remaining: 1.79s
# 643:	learn: 43574.3236253	total: 3.23s	remaining: 1.79s
# 644:	learn: 43562.2034467	total: 3.24s	remaining: 1.78s
# 645:	learn: 43553.3099871	total: 3.24s	remaining: 1.78s
# 646:	learn: 43547.7690321	total: 3.25s	remaining: 1.77s
# 647:	learn: 43534.7972641	total: 3.25s	remaining: 1.77s
# 648:	learn: 43527.2482617	total: 3.26s	remaining: 1.76s
# 649:	learn: 43523.2138610	total: 3.26s	remaining: 1.76s
# 650:	learn: 43515.4668825	total: 3.27s	remaining: 1.75s
# 651:	learn: 43502.5628133	total: 3.27s	remaining: 1.75s
# 652:	learn: 43489.8756581	total: 3.27s	remaining: 1.74s
# 653:	learn: 43481.2136210	total: 3.28s	remaining: 1.73s
# 654:	learn: 43466.4536455	total: 3.29s	remaining: 1.73s
# 655:	learn: 43457.7977239	total: 3.29s	remaining: 1.73s
# 656:	learn: 43439.8479776	total: 3.3s	remaining: 1.72s
# 657:	learn: 43431.4943769	total: 3.3s	remaining: 1.72s
# 658:	learn: 43426.6226189	total: 3.31s	remaining: 1.71s
# 659:	learn: 43418.0625092	total: 3.31s	remaining: 1.71s
# 660:	learn: 43413.0611278	total: 3.32s	remaining: 1.7s
# 661:	learn: 43404.6682425	total: 3.32s	remaining: 1.7s
# 662:	learn: 43398.7637452	total: 3.33s	remaining: 1.69s
# 663:	learn: 43390.9885762	total: 3.33s	remaining: 1.69s
# 664:	learn: 43379.0315800	total: 3.34s	remaining: 1.68s
# 665:	learn: 43371.9989188	total: 3.34s	remaining: 1.68s
# 666:	learn: 43358.3151989	total: 3.35s	remaining: 1.67s
# 667:	learn: 43348.9959187	total: 3.35s	remaining: 1.66s
# 668:	learn: 43346.3647251	total: 3.35s	remaining: 1.66s
# 669:	learn: 43337.6531248	total: 3.36s	remaining: 1.65s
# 670:	learn: 43332.5971418	total: 3.37s	remaining: 1.65s
# 671:	learn: 43324.8048481	total: 3.37s	remaining: 1.64s
# 672:	learn: 43307.4396142	total: 3.37s	remaining: 1.64s
# 673:	learn: 43299.6037254	total: 3.38s	remaining: 1.63s
# 674:	learn: 43280.4629160	total: 3.38s	remaining: 1.63s
# 675:	learn: 43276.7161795	total: 3.39s	remaining: 1.62s
# 676:	learn: 43268.6492213	total: 3.39s	remaining: 1.62s
# 677:	learn: 43257.5653718	total: 3.4s	remaining: 1.61s
# 678:	learn: 43248.3411743	total: 3.4s	remaining: 1.61s
# 679:	learn: 43242.2241945	total: 3.41s	remaining: 1.6s
# 680:	learn: 43232.3912114	total: 3.41s	remaining: 1.6s
# 681:	learn: 43221.0690853	total: 3.42s	remaining: 1.59s
# 682:	learn: 43212.3891459	total: 3.42s	remaining: 1.59s
# 683:	learn: 43202.0979690	total: 3.42s	remaining: 1.58s
# 684:	learn: 43191.5312769	total: 3.43s	remaining: 1.58s
# 685:	learn: 43178.5691031	total: 3.44s	remaining: 1.57s
# 686:	learn: 43171.6680006	total: 3.44s	remaining: 1.57s
# 687:	learn: 43164.0397955	total: 3.45s	remaining: 1.56s
# 688:	learn: 43152.4044168	total: 3.46s	remaining: 1.56s
# 689:	learn: 43143.0018647	total: 3.46s	remaining: 1.56s
# 690:	learn: 43129.9714862	total: 3.47s	remaining: 1.55s
# 691:	learn: 43118.5470734	total: 3.47s	remaining: 1.54s
# 692:	learn: 43105.8824137	total: 3.48s	remaining: 1.54s
# 693:	learn: 43098.8543189	total: 3.48s	remaining: 1.53s
# 694:	learn: 43090.8624456	total: 3.49s	remaining: 1.53s
# 695:	learn: 43080.4897772	total: 3.49s	remaining: 1.52s
# 696:	learn: 43071.4452024	total: 3.5s	remaining: 1.52s
# 697:	learn: 43067.4821348	total: 3.5s	remaining: 1.52s
# 698:	learn: 43056.5209280	total: 3.51s	remaining: 1.51s
# 699:	learn: 43039.2425126	total: 3.51s	remaining: 1.51s
# 700:	learn: 43031.5067561	total: 3.52s	remaining: 1.5s
# 701:	learn: 43023.6339236	total: 3.52s	remaining: 1.5s
# 702:	learn: 43018.2471229	total: 3.53s	remaining: 1.49s
# 703:	learn: 43012.3769003	total: 3.54s	remaining: 1.49s
# 704:	learn: 43005.3446475	total: 3.55s	remaining: 1.49s
# 705:	learn: 42996.0262380	total: 3.56s	remaining: 1.48s
# 706:	learn: 42986.4748784	total: 3.59s	remaining: 1.49s
# 707:	learn: 42972.8818025	total: 3.59s	remaining: 1.48s
# 708:	learn: 42967.8734320	total: 3.6s	remaining: 1.48s
# 709:	learn: 42960.3224451	total: 3.6s	remaining: 1.47s
# 710:	learn: 42945.2503893	total: 3.61s	remaining: 1.47s
# 711:	learn: 42937.2571222	total: 3.64s	remaining: 1.47s
# 712:	learn: 42930.9803267	total: 3.66s	remaining: 1.47s
# 713:	learn: 42923.3788935	total: 3.67s	remaining: 1.47s
# 714:	learn: 42918.4485833	total: 3.69s	remaining: 1.47s
# 715:	learn: 42907.0304359	total: 3.7s	remaining: 1.47s
# 716:	learn: 42900.7357995	total: 3.71s	remaining: 1.46s
# 717:	learn: 42887.8463533	total: 3.72s	remaining: 1.46s
# 718:	learn: 42881.4918278	total: 3.72s	remaining: 1.45s
# 719:	learn: 42863.2149340	total: 3.73s	remaining: 1.45s
# 720:	learn: 42849.9990497	total: 3.73s	remaining: 1.45s
# 721:	learn: 42844.2030796	total: 3.74s	remaining: 1.44s
# 722:	learn: 42830.8444831	total: 3.75s	remaining: 1.44s
# 723:	learn: 42824.9439961	total: 3.75s	remaining: 1.43s
# 724:	learn: 42815.8966409	total: 3.76s	remaining: 1.43s
# 725:	learn: 42811.1842504	total: 3.77s	remaining: 1.42s
# 726:	learn: 42806.8904058	total: 3.77s	remaining: 1.42s
# 727:	learn: 42800.3663160	total: 3.78s	remaining: 1.41s
# 728:	learn: 42795.9774513	total: 3.78s	remaining: 1.41s
# 729:	learn: 42791.2054562	total: 3.79s	remaining: 1.4s
# 730:	learn: 42783.2548752	total: 3.8s	remaining: 1.4s
# 731:	learn: 42775.6903584	total: 3.8s	remaining: 1.39s
# 732:	learn: 42763.4504038	total: 3.81s	remaining: 1.39s
# 733:	learn: 42752.1248840	total: 3.81s	remaining: 1.38s
# 734:	learn: 42743.5076179	total: 3.82s	remaining: 1.38s
# 735:	learn: 42737.4407068	total: 3.82s	remaining: 1.37s
# 736:	learn: 42734.3257586	total: 3.83s	remaining: 1.37s
# 737:	learn: 42729.5312886	total: 3.83s	remaining: 1.36s
# 738:	learn: 42727.0585783	total: 3.84s	remaining: 1.35s
# 739:	learn: 42721.8689876	total: 3.84s	remaining: 1.35s
# 740:	learn: 42714.3144418	total: 3.85s	remaining: 1.34s
# 741:	learn: 42702.9520365	total: 3.85s	remaining: 1.34s
# 742:	learn: 42698.6491610	total: 3.86s	remaining: 1.33s
# 743:	learn: 42691.4985367	total: 3.86s	remaining: 1.33s
# 744:	learn: 42677.6800087	total: 3.87s	remaining: 1.32s
# 745:	learn: 42663.4827002	total: 3.87s	remaining: 1.32s
# 746:	learn: 42654.1416908	total: 3.88s	remaining: 1.31s
# 747:	learn: 42646.6607782	total: 3.88s	remaining: 1.31s
# 748:	learn: 42641.0965271	total: 3.89s	remaining: 1.3s
# 749:	learn: 42637.2796334	total: 3.89s	remaining: 1.3s
# 750:	learn: 42631.4325787	total: 3.9s	remaining: 1.29s
# 751:	learn: 42613.7916047	total: 3.9s	remaining: 1.29s
# 752:	learn: 42604.5001863	total: 3.91s	remaining: 1.28s
# 753:	learn: 42596.8315724	total: 3.91s	remaining: 1.28s
# 754:	learn: 42593.1117335	total: 3.92s	remaining: 1.27s
# 755:	learn: 42583.9559944	total: 3.92s	remaining: 1.27s
# 756:	learn: 42581.3783430	total: 3.93s	remaining: 1.26s
# 757:	learn: 42571.4178165	total: 3.93s	remaining: 1.25s
# 758:	learn: 42565.4031072	total: 3.94s	remaining: 1.25s
# 759:	learn: 42560.6090403	total: 3.94s	remaining: 1.25s
# 760:	learn: 42556.5885193	total: 3.95s	remaining: 1.24s
# 761:	learn: 42544.9583021	total: 3.96s	remaining: 1.24s
# 762:	learn: 42537.4825439	total: 3.96s	remaining: 1.23s
# 763:	learn: 42531.2664227	total: 3.97s	remaining: 1.23s
# 764:	learn: 42522.3802844	total: 3.98s	remaining: 1.22s
# 765:	learn: 42515.7238548	total: 3.98s	remaining: 1.22s
# 766:	learn: 42508.6665482	total: 3.99s	remaining: 1.21s
# 767:	learn: 42495.7392400	total: 3.99s	remaining: 1.21s
# 768:	learn: 42486.5841643	total: 4s	remaining: 1.2s
# 769:	learn: 42481.0476392	total: 4s	remaining: 1.2s
# 770:	learn: 42474.6358279	total: 4.01s	remaining: 1.19s
# 771:	learn: 42467.5454563	total: 4.01s	remaining: 1.19s
# 772:	learn: 42460.2113172	total: 4.02s	remaining: 1.18s
# 773:	learn: 42454.0604061	total: 4.03s	remaining: 1.18s
# 774:	learn: 42447.2358285	total: 4.03s	remaining: 1.17s
# 775:	learn: 42440.7520140	total: 4.03s	remaining: 1.16s
# 776:	learn: 42436.3873290	total: 4.04s	remaining: 1.16s
# 777:	learn: 42431.0107131	total: 4.04s	remaining: 1.15s
# 778:	learn: 42425.3848780	total: 4.05s	remaining: 1.15s
# 779:	learn: 42418.2675507	total: 4.06s	remaining: 1.14s
# 780:	learn: 42413.8577721	total: 4.06s	remaining: 1.14s
# 781:	learn: 42407.5338616	total: 4.07s	remaining: 1.13s
# 782:	learn: 42400.3297003	total: 4.07s	remaining: 1.13s
# 783:	learn: 42393.3768041	total: 4.08s	remaining: 1.12s
# 784:	learn: 42384.4111134	total: 4.08s	remaining: 1.12s
# 785:	learn: 42372.2073377	total: 4.09s	remaining: 1.11s
# 786:	learn: 42368.3579134	total: 4.09s	remaining: 1.11s
# 787:	learn: 42361.8929748	total: 4.1s	remaining: 1.1s
# 788:	learn: 42357.7249687	total: 4.11s	remaining: 1.1s
# 789:	learn: 42349.3775356	total: 4.11s	remaining: 1.09s
# 790:	learn: 42346.5326248	total: 4.12s	remaining: 1.09s
# 791:	learn: 42334.2205793	total: 4.13s	remaining: 1.08s
# 792:	learn: 42325.2142241	total: 4.14s	remaining: 1.08s
# 793:	learn: 42314.2570541	total: 4.15s	remaining: 1.08s
# 794:	learn: 42307.6678875	total: 4.16s	remaining: 1.07s
# 795:	learn: 42301.6141466	total: 4.17s	remaining: 1.07s
# 796:	learn: 42296.3347767	total: 4.18s	remaining: 1.06s
# 797:	learn: 42287.7353062	total: 4.18s	remaining: 1.06s
# 798:	learn: 42283.0706869	total: 4.2s	remaining: 1.05s
# 799:	learn: 42277.2939918	total: 4.2s	remaining: 1.05s
# 800:	learn: 42272.5858635	total: 4.21s	remaining: 1.04s
# 801:	learn: 42267.2600314	total: 4.21s	remaining: 1.04s
# 802:	learn: 42258.6170389	total: 4.22s	remaining: 1.03s
# 803:	learn: 42255.3301009	total: 4.23s	remaining: 1.03s
# 804:	learn: 42244.7585812	total: 4.23s	remaining: 1.02s
# 805:	learn: 42238.0885658	total: 4.24s	remaining: 1.02s
# 806:	learn: 42233.9421960	total: 4.25s	remaining: 1.02s
# 807:	learn: 42230.6529751	total: 4.28s	remaining: 1.02s
# 808:	learn: 42214.6742412	total: 4.29s	remaining: 1.01s
# 809:	learn: 42203.4996858	total: 4.3s	remaining: 1.01s
# 810:	learn: 42195.6499597	total: 4.31s	remaining: 1s
# 811:	learn: 42192.1925750	total: 4.32s	remaining: 1s
# 812:	learn: 42180.2595174	total: 4.33s	remaining: 996ms
# 813:	learn: 42170.0268478	total: 4.34s	remaining: 991ms
# 814:	learn: 42161.4037620	total: 4.34s	remaining: 985ms
# 815:	learn: 42158.3442043	total: 4.35s	remaining: 981ms
# 816:	learn: 42151.8228081	total: 4.36s	remaining: 978ms
# 817:	learn: 42138.3323375	total: 4.37s	remaining: 973ms
# 818:	learn: 42127.5092233	total: 4.38s	remaining: 968ms
# 819:	learn: 42119.5312296	total: 4.39s	remaining: 964ms
# 820:	learn: 42112.0132602	total: 4.4s	remaining: 959ms
# 821:	learn: 42108.7501673	total: 4.4s	remaining: 953ms
# 822:	learn: 42103.6127784	total: 4.41s	remaining: 948ms
# 823:	learn: 42099.2379836	total: 4.42s	remaining: 945ms
# 824:	learn: 42094.6902089	total: 4.43s	remaining: 940ms
# 825:	learn: 42085.0112748	total: 4.44s	remaining: 935ms
# 826:	learn: 42081.2675018	total: 4.44s	remaining: 930ms
# 827:	learn: 42070.0504258	total: 4.45s	remaining: 924ms
# 828:	learn: 42065.7256149	total: 4.45s	remaining: 919ms
# 829:	learn: 42059.5409386	total: 4.46s	remaining: 913ms
# 830:	learn: 42049.9905371	total: 4.46s	remaining: 908ms
# 831:	learn: 42044.0309025	total: 4.47s	remaining: 902ms
# 832:	learn: 42037.0465260	total: 4.47s	remaining: 897ms
# 833:	learn: 42028.7566461	total: 4.48s	remaining: 891ms
# 834:	learn: 42018.3989259	total: 4.49s	remaining: 886ms
# 835:	learn: 42013.0388318	total: 4.49s	remaining: 881ms
# 836:	learn: 42006.2449576	total: 4.49s	remaining: 875ms
# 837:	learn: 42000.4219054	total: 4.5s	remaining: 870ms
# 838:	learn: 41991.8777028	total: 4.5s	remaining: 864ms
# 839:	learn: 41981.3923068	total: 4.5s	remaining: 858ms
# 840:	learn: 41975.5057256	total: 4.51s	remaining: 853ms
# 841:	learn: 41969.0343459	total: 4.51s	remaining: 847ms
# 842:	learn: 41961.3559595	total: 4.52s	remaining: 841ms
# 843:	learn: 41954.4347442	total: 4.52s	remaining: 836ms
# 844:	learn: 41947.5840893	total: 4.52s	remaining: 830ms
# 845:	learn: 41942.3404921	total: 4.53s	remaining: 824ms
# 846:	learn: 41937.4019291	total: 4.53s	remaining: 819ms
# 847:	learn: 41930.8955016	total: 4.54s	remaining: 813ms
# 848:	learn: 41924.2500022	total: 4.54s	remaining: 808ms
# 849:	learn: 41918.2772979	total: 4.54s	remaining: 802ms
# 850:	learn: 41916.7651996	total: 4.55s	remaining: 796ms
# 851:	learn: 41907.6910489	total: 4.55s	remaining: 791ms
# 852:	learn: 41902.1195477	total: 4.56s	remaining: 786ms
# 853:	learn: 41892.9564613	total: 4.56s	remaining: 780ms
# 854:	learn: 41887.4412435	total: 4.57s	remaining: 775ms
# 855:	learn: 41879.5306992	total: 4.57s	remaining: 769ms
# 856:	learn: 41873.4582382	total: 4.58s	remaining: 763ms
# 857:	learn: 41869.3766602	total: 4.58s	remaining: 758ms
# 858:	learn: 41860.4879883	total: 4.58s	remaining: 752ms
# 859:	learn: 41853.2102676	total: 4.59s	remaining: 747ms
# 860:	learn: 41847.3740802	total: 4.59s	remaining: 741ms
# 861:	learn: 41842.6898136	total: 4.59s	remaining: 736ms
# 862:	learn: 41838.2875529	total: 4.6s	remaining: 730ms
# 863:	learn: 41828.0378224	total: 4.6s	remaining: 725ms
# 864:	learn: 41820.4439331	total: 4.61s	remaining: 719ms
# 865:	learn: 41808.4783094	total: 4.61s	remaining: 713ms
# 866:	learn: 41804.0980228	total: 4.62s	remaining: 708ms
# 867:	learn: 41800.2626932	total: 4.62s	remaining: 702ms
# 868:	learn: 41796.5714787	total: 4.62s	remaining: 697ms
# 869:	learn: 41791.8244674	total: 4.63s	remaining: 691ms
# 870:	learn: 41788.3271651	total: 4.63s	remaining: 686ms
# 871:	learn: 41782.6538700	total: 4.63s	remaining: 680ms
# 872:	learn: 41778.6297284	total: 4.64s	remaining: 675ms
# 873:	learn: 41774.5535258	total: 4.64s	remaining: 669ms
# 874:	learn: 41770.7994842	total: 4.65s	remaining: 664ms
# 875:	learn: 41768.0784465	total: 4.65s	remaining: 658ms
# 876:	learn: 41761.5571747	total: 4.65s	remaining: 653ms
# 877:	learn: 41758.5154669	total: 4.66s	remaining: 647ms
# 878:	learn: 41751.6811796	total: 4.66s	remaining: 642ms
# 879:	learn: 41748.5854799	total: 4.67s	remaining: 636ms
# 880:	learn: 41742.2025352	total: 4.67s	remaining: 631ms
# 881:	learn: 41738.2420562	total: 4.67s	remaining: 625ms
# 882:	learn: 41733.6597919	total: 4.68s	remaining: 620ms
# 883:	learn: 41724.5219008	total: 4.68s	remaining: 614ms
# 884:	learn: 41720.0100302	total: 4.69s	remaining: 609ms
# 885:	learn: 41711.4537361	total: 4.69s	remaining: 604ms
# 886:	learn: 41708.2371911	total: 4.7s	remaining: 598ms
# 887:	learn: 41699.6043538	total: 4.7s	remaining: 593ms
# 888:	learn: 41686.7619743	total: 4.71s	remaining: 588ms
# 889:	learn: 41683.0675242	total: 4.72s	remaining: 583ms
# 890:	learn: 41680.8805019	total: 4.73s	remaining: 579ms
# 891:	learn: 41677.4647886	total: 4.75s	remaining: 575ms
# 892:	learn: 41667.5109935	total: 4.76s	remaining: 570ms
# 893:	learn: 41658.2115320	total: 4.76s	remaining: 565ms
# 894:	learn: 41648.9433848	total: 4.77s	remaining: 560ms
# 895:	learn: 41646.2111445	total: 4.78s	remaining: 555ms
# 896:	learn: 41642.4403609	total: 4.79s	remaining: 549ms
# 897:	learn: 41638.0935717	total: 4.79s	remaining: 544ms
# 898:	learn: 41632.6216058	total: 4.79s	remaining: 539ms
# 899:	learn: 41625.8486504	total: 4.8s	remaining: 533ms
# 900:	learn: 41620.6935737	total: 4.8s	remaining: 528ms
# 901:	learn: 41610.5317827	total: 4.81s	remaining: 522ms
# 902:	learn: 41604.3568387	total: 4.81s	remaining: 517ms
# 903:	learn: 41601.0502737	total: 4.82s	remaining: 512ms
# 904:	learn: 41596.4731075	total: 4.82s	remaining: 506ms
# 905:	learn: 41591.0404792	total: 4.82s	remaining: 501ms
# 906:	learn: 41586.3053382	total: 4.83s	remaining: 495ms
# 907:	learn: 41582.4995063	total: 4.83s	remaining: 490ms
# 908:	learn: 41576.0141402	total: 4.84s	remaining: 484ms
# 909:	learn: 41570.6701399	total: 4.84s	remaining: 479ms
# 910:	learn: 41557.7785260	total: 4.85s	remaining: 474ms
# 911:	learn: 41555.2554732	total: 4.85s	remaining: 468ms
# 912:	learn: 41544.7865452	total: 4.86s	remaining: 463ms
# 913:	learn: 41536.7482081	total: 4.86s	remaining: 457ms
# 914:	learn: 41532.1071014	total: 4.87s	remaining: 452ms
# 915:	learn: 41529.6350066	total: 4.87s	remaining: 447ms
# 916:	learn: 41524.4161174	total: 4.87s	remaining: 441ms
# 917:	learn: 41514.8934234	total: 4.88s	remaining: 436ms
# 918:	learn: 41510.2925319	total: 4.88s	remaining: 430ms
# 919:	learn: 41505.7314445	total: 4.89s	remaining: 425ms
# 920:	learn: 41501.6738835	total: 4.89s	remaining: 420ms
# 921:	learn: 41497.5478170	total: 4.89s	remaining: 414ms
# 922:	learn: 41494.5088089	total: 4.9s	remaining: 409ms
# 923:	learn: 41485.0043326	total: 4.9s	remaining: 403ms
# 924:	learn: 41479.2567092	total: 4.91s	remaining: 398ms
# 925:	learn: 41475.2228811	total: 4.91s	remaining: 393ms
# 926:	learn: 41471.2028530	total: 4.92s	remaining: 387ms
# 927:	learn: 41468.5246789	total: 4.92s	remaining: 382ms
# 928:	learn: 41460.4503964	total: 4.92s	remaining: 376ms
# 929:	learn: 41452.0498712	total: 4.93s	remaining: 371ms
# 930:	learn: 41447.2245261	total: 4.93s	remaining: 366ms
# 931:	learn: 41442.9097358	total: 4.94s	remaining: 360ms
# 932:	learn: 41437.1772834	total: 4.94s	remaining: 355ms
# 933:	learn: 41429.2835123	total: 4.94s	remaining: 349ms
# 934:	learn: 41425.1891810	total: 4.95s	remaining: 344ms
# 935:	learn: 41420.0759411	total: 4.95s	remaining: 339ms
# 936:	learn: 41416.6570754	total: 4.96s	remaining: 333ms
# 937:	learn: 41413.8657526	total: 4.96s	remaining: 328ms
# 938:	learn: 41410.1045447	total: 4.96s	remaining: 322ms
# 939:	learn: 41403.1044732	total: 4.97s	remaining: 317ms
# 940:	learn: 41400.4451664	total: 4.97s	remaining: 312ms
# 941:	learn: 41397.3088569	total: 4.98s	remaining: 306ms
# 942:	learn: 41393.8637137	total: 4.98s	remaining: 301ms
# 943:	learn: 41390.2785079	total: 4.99s	remaining: 296ms
# 944:	learn: 41380.6859758	total: 4.99s	remaining: 290ms
# 945:	learn: 41372.9702148	total: 4.99s	remaining: 285ms
# 946:	learn: 41365.8858782	total: 5s	remaining: 280ms
# 947:	learn: 41364.4722513	total: 5.01s	remaining: 275ms
# 948:	learn: 41362.0968840	total: 5.01s	remaining: 269ms
# 949:	learn: 41356.8151217	total: 5.01s	remaining: 264ms
# 950:	learn: 41350.1163780	total: 5.02s	remaining: 259ms
# 951:	learn: 41344.5882827	total: 5.02s	remaining: 253ms
# 952:	learn: 41339.3892819	total: 5.03s	remaining: 248ms
# 953:	learn: 41331.9391051	total: 5.03s	remaining: 243ms
# 954:	learn: 41328.4109468	total: 5.04s	remaining: 237ms
# 955:	learn: 41326.3581587	total: 5.04s	remaining: 232ms
# 956:	learn: 41320.0654159	total: 5.05s	remaining: 227ms
# 957:	learn: 41315.3430056	total: 5.05s	remaining: 221ms
# 958:	learn: 41307.6564809	total: 5.05s	remaining: 216ms
# 959:	learn: 41302.9090081	total: 5.06s	remaining: 211ms
# 960:	learn: 41298.5281427	total: 5.06s	remaining: 205ms
# 961:	learn: 41295.7117598	total: 5.07s	remaining: 200ms
# 962:	learn: 41290.0249050	total: 5.07s	remaining: 195ms
# 963:	learn: 41287.0093083	total: 5.07s	remaining: 190ms
# 964:	learn: 41282.6131165	total: 5.08s	remaining: 184ms
# 965:	learn: 41277.1742335	total: 5.08s	remaining: 179ms
# 966:	learn: 41272.2745109	total: 5.09s	remaining: 174ms
# 967:	learn: 41263.3842927	total: 5.09s	remaining: 168ms
# 968:	learn: 41260.2987826	total: 5.09s	remaining: 163ms
# 969:	learn: 41252.5732147	total: 5.1s	remaining: 158ms
# 970:	learn: 41249.7824891	total: 5.1s	remaining: 152ms
# 971:	learn: 41246.1287593	total: 5.11s	remaining: 147ms
# 972:	learn: 41237.4621770	total: 5.11s	remaining: 142ms
# 973:	learn: 41234.4975271	total: 5.12s	remaining: 137ms
# 974:	learn: 41227.2230999	total: 5.12s	remaining: 131ms
# 975:	learn: 41222.7154842	total: 5.13s	remaining: 126ms
# 976:	learn: 41215.3502050	total: 5.13s	remaining: 121ms
# 977:	learn: 41211.3437846	total: 5.13s	remaining: 116ms
# 978:	learn: 41202.2140282	total: 5.14s	remaining: 110ms
# 979:	learn: 41195.4898692	total: 5.14s	remaining: 105ms
# 980:	learn: 41189.3351358	total: 5.15s	remaining: 99.7ms
# 981:	learn: 41186.4197175	total: 5.15s	remaining: 94.4ms
# 982:	learn: 41168.2974361	total: 5.15s	remaining: 89.1ms
# 983:	learn: 41164.4775256	total: 5.16s	remaining: 83.9ms
# 984:	learn: 41157.2600939	total: 5.16s	remaining: 78.6ms
# 985:	learn: 41151.8071676	total: 5.17s	remaining: 73.3ms
# 986:	learn: 41147.2688763	total: 5.17s	remaining: 68.1ms
# 987:	learn: 41145.9747565	total: 5.17s	remaining: 62.9ms
# 988:	learn: 41140.4733593	total: 5.18s	remaining: 57.6ms
# 989:	learn: 41133.9264083	total: 5.18s	remaining: 52.4ms
# 990:	learn: 41121.3194310	total: 5.19s	remaining: 47.1ms
# 991:	learn: 41116.8604479	total: 5.19s	remaining: 41.9ms
# 992:	learn: 41115.8056117	total: 5.19s	remaining: 36.6ms
# 993:	learn: 41114.9203544	total: 5.2s	remaining: 31.4ms
# 994:	learn: 41106.4180799	total: 5.2s	remaining: 26.1ms
# 995:	learn: 41102.2028474	total: 5.21s	remaining: 20.9ms
# 996:	learn: 41094.9925845	total: 5.21s	remaining: 15.7ms
# 997:	learn: 41087.1710907	total: 5.21s	remaining: 10.5ms
# 998:	learn: 41079.1557988	total: 5.22s	remaining: 5.22ms
# 999:	learn: 41066.2927583	total: 5.22s	remaining: 0us
# prediction...
# >CatBoost 0.841 (0.000)
# memory RAM released.
# memory RAM released.
# setting the pipeline object ...
# preprocessor...
# preprocessing: the categorical and numerical feature now...
# One Hot Encoder...
# categorical features: ['ocean_proximity']
# >>> pipeline defined!
# prediction...
# >LinearR 0.612 (0.000)
# memory RAM released.
# memory RAM released.

# %%
feature_names =list(X.columns)

# %%
# feature importance
for name, model in models.items():

    if(name == 'LinearR'):
        continue

    list_feat_importances = list(model.feature_importances_)
    print(list_feat_importances)
    
    dict_feat_importances = {}

    print('features selected:')
    mask = pipe.named_steps['fs'].get_support()

    new_features = [] # The list of your K best features

    for bool, feature in zip(mask, feature_names):
        if(bool and (feature != 'p_esc_final')):
            new_features.append(feature)
            
    print(f'the K best features selected to the model ({name}): {new_features}')

    i=0

    print('######################################################################')
    print(f'model: {name}')

    # list of feature importances
    for ilist in new_features:

        if(name=='CatBoost'):
            dict_feat_importances[ilist] = list_feat_importances[i] # porcentagem %
            print(f"{ilist}.......: {round(dict_feat_importances[ilist], 2)} %")
            i=i+1
        else:
            dict_feat_importances[ilist] = list_feat_importances[i]*100 # porcentagem %
            print(f"{ilist}.......: {round(dict_feat_importances[ilist], 2)} %")
            i=i+1

    x_axis = list(dict_feat_importances.values())
    y_axis = list(dict_feat_importances.keys())

    sns.barplot(x_axis, y_axis)
    
    plt.ylabel('features', fontsize=12)
    plt.xlabel('Feature Importance')
    plt.title(f"Model - {name}")
    plt.savefig(f'figures/feature_importance_model_{name}.png')
    plt.savefig(f'figures/feature_importance_model_{name}.pdf')
    # Show graphic
    plt.show()


    print('######################################################################')
# Out:
# [0.16581896209736796, 0.16646571958658746, 0.511405209362698, 0.00866979853079018, 0.14764031042255654]
# features selected:
# the K best features selected to the model (RandomForest): ['longitude', 'latitude', 'median_income', 'ocean_proximity']
# ######################################################################
# model: RandomForest
# longitude.......: 16.58 %
# latitude.......: 16.65 %
# median_income.......: 51.14 %
# ocean_proximity.......: 0.87 %
# /home/andsilva/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ######################################################################
# [0.1728950222509941, 0.1643286482621477, 0.5087801185084377, 0.007690612007369679, 0.14630559897105086]
# features selected:
# the K best features selected to the model (DecisionTree): ['longitude', 'latitude', 'median_income', 'ocean_proximity']
# ######################################################################
# model: DecisionTree
# longitude.......: 17.29 %
# latitude.......: 16.43 %
# median_income.......: 50.88 %
# ocean_proximity.......: 0.77 %
# /home/andsilva/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ######################################################################
# [0.020368561, 0.021457452, 0.07951609, 0.02226927, 0.8563886]
# features selected:
# the K best features selected to the model (XGBoost): ['longitude', 'latitude', 'median_income', 'ocean_proximity']
# ######################################################################
# model: XGBoost
# longitude.......: 2.04 %
# latitude.......: 2.15 %
# median_income.......: 7.95 %
# ocean_proximity.......: 2.23 %
# /home/andsilva/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ######################################################################
# [28.904977143484412, 27.744153155842177, 25.00981367103331, 2.740801320048452, 15.600254709591653]
# features selected:
# the K best features selected to the model (CatBoost): ['longitude', 'latitude', 'median_income', 'ocean_proximity']
# ######################################################################
# model: CatBoost
# longitude.......: 28.9 %
# latitude.......: 27.74 %
# median_income.......: 25.01 %
# ocean_proximity.......: 2.74 %
# /home/andsilva/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ######################################################################

# %%
time_exec_min = round( (time.time() - start_time)/60, 4)
    
print(f'time of execution (total pipeline): {time_exec_min} minutes')
# datetime object containing current date and time
now = datetime.now()

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print(">>> date: ", dt_string)
print('Done! please, check the results. :)')
# Out:
# time of execution (total pipeline): 0.3343 minutes
# >>> date:  03/09/2021 19:08:32
# Done! please, check the results. :)
