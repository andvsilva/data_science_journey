# %%
import numpy as np
import torch
import torch.nn as nn
import sys

# %%
def wSum(X,W):
    h = torch.from_numpy(X)
    z = torch.matmul(W,h)
    return z

# %%
def activate(x):
    return 1/(1+torch.exp(-x))

# %%
def forwardStep(X,W_list):
    h = torch.from_numpy(X)
    for W in W_list:
        z = torch.matmul(W,h)
        h = activate(z)
    return h

# %%
def updateParams(W_list, dW_list, lr):
    with torch.no_grad():
        for i in range(len(W_list)):
            W_list[i] -= lr*dW_list[i]
    return W_list

# %%
def trainNN_sgd(X,y,W_list,loss_fn,lr=0.0001,nepochs=100):
    for epoch in range(nepochs):
        avgLoss = []
        for i in range(len(y)):
            Xin = X[i,:]
            yTrue = y[i]
            y_hat = forwardStep(Xin,W_list)
            loss = loss_fn(y_hat,torch.tensor(yTrue,dtype=torch.double))
            loss.backward()
            avgLoss.append(loss.item())
            sys.stdout.flush()
            dW_list = []
            for j in range(len(W_list)):
                dW_list.append(W_list[j].grad.data)
            W_list = updateParams(W_list,dW_list,lr)
            for j in range(len(W_list)):
                W_list[j].grad.data.zero_()
        
        print("loss after epoch=%d: %f" %(epoch, np.mean(np.array(avgLoss))))
    return W_list

# %%
def trainNN_batch(X,y,W_list,loss_fn,lr=0.0001,nepochs=100):
    n = len(y)
    for epoch in range(nepochs):
        loss = 0
        for i in range(len(y)):
            Xin = X[i,:]
            yTrue = y[i]
            y_hat = forwardStep(Xin,W_list)
            loss += loss_fn(y_hat,torch.tensor(yTrue,dtype=torch.double))
        loss = loss/n
        loss.backward()
        sys.stdout.flush()
        dW_list = []
        for j in range(len(W_list)):
            dW_list.append(W_list[j].grad.data)
        W_list = updateParams(W_list,dW_list,lr)
        for j in range(len(W_list)):
            W_list[j].grad.data.zero_()
        
        print("loss after epoch=%d: %f" %(epoch, loss))
    return W_list

# %%
def trainNN_minibatch(X,y,W_list,loss_fn,lr=0.0001,nepochs=100,batchSize=16):
    n = len(y)
    numBatches = n//batchSize
    
    for epoch in range(nepochs):
        for batch in range(numBatches):
            X_batch = X[batch*batchSize:(batch+1)*batchSize,:]
            y_batch = y[batch*batchSize:(batch+1)*batchSize]
            loss = 0
            for i in range(batchSize):
                Xin = X_batch[i,:]
                yTrue = y_batch[i]
                y_hat = forwardStep(Xin,W_list)
                loss += loss_fn(y_hat,torch.tensor(yTrue,dtype=torch.double))
            loss = loss/batchSize
            loss.backward()
            sys.stdout.flush()
            dW_list = []
            for j in range(len(W_list)):
                dW_list.append(W_list[j].grad.data)
            W_list = updateParams(W_list,dW_list,lr)
            for j in range(len(W_list)):
                W_list[j].grad.data.zero_()
            
            print("loss after epoch=%d: %f" %(epoch, loss/numBatches))
    return W_list

# %%
inputDim = 10
n = 1000
X = np.random.rand(n,inputDim)
y = np.random.randint(0,2,n)

W1 = torch.tensor(np.random.uniform(0,1,(2,inputDim)),requires_grad=True)
W2 = torch.tensor(np.random.uniform(0,1,(3,2)),requires_grad=True)
W3 = torch.tensor(np.random.uniform(0,1,3),requires_grad=True)

W_list = []
W_list.append(W1)
W_list.append(W2)
W_list.append(W3)

loss_fn = nn.BCELoss()
#W_list = trainNN_sgd(X,y,W_list,loss_fn,lr=0.0001,nepochs=100)
#W_list = trainNN_batch(X,y,W_list,loss_fn,lr=0.0001,nepochs=100)
W_list = trainNN_minibatch(X,y,W_list,loss_fn,lr=0.0001,nepochs=100)
# Out:
# loss after epoch=0: 0.014858
# loss after epoch=0: 0.022018
# loss after epoch=0: 0.016711
# loss after epoch=0: 0.016718
# loss after epoch=0: 0.009614
# loss after epoch=0: 0.018516
# loss after epoch=0: 0.011418
# loss after epoch=0: 0.014911
# loss after epoch=0: 0.016657
# loss after epoch=0: 0.018527
# loss after epoch=0: 0.025518
# loss after epoch=0: 0.011442
# loss after epoch=0: 0.021950
# loss after epoch=0: 0.020259
# loss after epoch=0: 0.018448
# loss after epoch=0: 0.009662
# loss after epoch=0: 0.014934
# loss after epoch=0: 0.018531
# loss after epoch=0: 0.011374
# loss after epoch=0: 0.016597
# loss after epoch=0: 0.023847
# loss after epoch=0: 0.018540
# loss after epoch=0: 0.020143
# loss after epoch=0: 0.014943
# loss after epoch=0: 0.016734
# loss after epoch=0: 0.020216
# loss after epoch=0: 0.016666
# loss after epoch=0: 0.018473
# loss after epoch=0: 0.016719
# loss after epoch=0: 0.016676
# loss after epoch=0: 0.018483
# loss after epoch=0: 0.018421
# loss after epoch=0: 0.016725
# loss after epoch=0: 0.020228
# loss after epoch=0: 0.018475
# loss after epoch=0: 0.018474
# loss after epoch=0: 0.014960
# loss after epoch=0: 0.018493
# loss after epoch=0: 0.022052
# loss after epoch=0: 0.018431
# loss after epoch=0: 0.016660
# loss after epoch=0: 0.011459
# loss after epoch=0: 0.018411
# loss after epoch=0: 0.023700
# loss after epoch=0: 0.016691
# loss after epoch=0: 0.014971
# loss after epoch=0: 0.013181
# loss after epoch=0: 0.018371
# loss after epoch=0: 0.016739
# loss after epoch=0: 0.025494
# loss after epoch=0: 0.014920
# loss after epoch=0: 0.013180
# loss after epoch=0: 0.013211
# loss after epoch=0: 0.013155
# loss after epoch=0: 0.009675
# loss after epoch=0: 0.013196
# loss after epoch=0: 0.018452
# loss after epoch=0: 0.023729
# loss after epoch=0: 0.018521
# loss after epoch=0: 0.009609
# loss after epoch=0: 0.013199
# loss after epoch=0: 0.014931
# loss after epoch=1: 0.014839
# loss after epoch=1: 0.021983
# loss after epoch=1: 0.016689
# loss after epoch=1: 0.016695
# loss after epoch=1: 0.009607
# loss after epoch=1: 0.018489
# loss after epoch=1: 0.011408
# loss after epoch=1: 0.014892
# loss after epoch=1: 0.016634
# loss after epoch=1: 0.018499
# loss after epoch=1: 0.025474
# loss after epoch=1: 0.011432
# loss after epoch=1: 0.021915
# loss after epoch=1: 0.020228
# loss after epoch=1: 0.018421
# loss after epoch=1: 0.009655
# loss after epoch=1: 0.014915
# loss after epoch=1: 0.018504
# loss after epoch=1: 0.011363
# loss after epoch=1: 0.016574
# loss after epoch=1: 0.023807
# loss after epoch=1: 0.018512
# loss after epoch=1: 0.020112
# loss after epoch=1: 0.014924
# loss after epoch=1: 0.016711
# loss after epoch=1: 0.020185
# loss after epoch=1: 0.016643
# loss after epoch=1: 0.018446
# loss after epoch=1: 0.016696
# loss after epoch=1: 0.016653
# loss after epoch=1: 0.018456
# loss after epoch=1: 0.018395
# loss after epoch=1: 0.016702
# loss after epoch=1: 0.020197
# loss after epoch=1: 0.018448
# loss after epoch=1: 0.018447
# loss after epoch=1: 0.014941
# loss after epoch=1: 0.018466
# loss after epoch=1: 0.022017
# loss after epoch=1: 0.018404
# loss after epoch=1: 0.016638
# loss after epoch=1: 0.011448
# loss after epoch=1: 0.018384
# loss after epoch=1: 0.023661
# loss after epoch=1: 0.016668
# loss after epoch=1: 0.014952
# loss after epoch=1: 0.013166
# loss after epoch=1: 0.018344
# loss after epoch=1: 0.016716
# loss after epoch=1: 0.025451
# loss after epoch=1: 0.014901
# loss after epoch=1: 0.013165
# loss after epoch=1: 0.013196
# loss after epoch=1: 0.013140
# loss after epoch=1: 0.009668
# loss after epoch=1: 0.013181
# loss after epoch=1: 0.018425
# loss after epoch=1: 0.023690
# loss after epoch=1: 0.018494
# loss after epoch=1: 0.009603
# loss after epoch=1: 0.013184
# loss after epoch=1: 0.014913
# loss after epoch=2: 0.014821
# loss after epoch=2: 0.021948
# loss after epoch=2: 0.016666
# loss after epoch=2: 0.016673
# loss after epoch=2: 0.009601
# loss after epoch=2: 0.018462
# loss after epoch=2: 0.011397
# loss after epoch=2: 0.014874
# loss after epoch=2: 0.016612
# loss after epoch=2: 0.018472
# loss after epoch=2: 0.025431
# loss after epoch=2: 0.011421
# loss after epoch=2: 0.021880
# loss after epoch=2: 0.020197
# loss after epoch=2: 0.018394
# loss after epoch=2: 0.009648
# loss after epoch=2: 0.014896
# loss after epoch=2: 0.018477
# loss after epoch=2: 0.011353
# loss after epoch=2: 0.016552
# loss after epoch=2: 0.023768
# loss after epoch=2: 0.018485
# loss after epoch=2: 0.020081
# loss after epoch=2: 0.014905
# loss after epoch=2: 0.016688
# loss after epoch=2: 0.020154
# loss after epoch=2: 0.016620
# loss after epoch=2: 0.018419
# loss after epoch=2: 0.016673
# loss after epoch=2: 0.016631
# loss after epoch=2: 0.018429
# loss after epoch=2: 0.018368
# loss after epoch=2: 0.016679
# loss after epoch=2: 0.020166
# loss after epoch=2: 0.018421
# loss after epoch=2: 0.018420
# loss after epoch=2: 0.014922
# loss after epoch=2: 0.018439
# loss after epoch=2: 0.021982
# loss after epoch=2: 0.018377
# loss after epoch=2: 0.016615
# loss after epoch=2: 0.011437
# loss after epoch=2: 0.018357
# loss after epoch=2: 0.023622
# loss after epoch=2: 0.016646
# loss after epoch=2: 0.014933
# loss after epoch=2: 0.013151
# loss after epoch=2: 0.018318
# loss after epoch=2: 0.016693
# loss after epoch=2: 0.025408
# loss after epoch=2: 0.014883
# loss after epoch=2: 0.013151
# loss after epoch=2: 0.013181
# loss after epoch=2: 0.013125
# loss after epoch=2: 0.009662
# loss after epoch=2: 0.013166
# loss after epoch=2: 0.018399
# loss after epoch=2: 0.023651
# loss after epoch=2: 0.018467
# loss after epoch=2: 0.009596
# loss after epoch=2: 0.013169
# loss after epoch=2: 0.014894
# loss after epoch=3: 0.014802
# loss after epoch=3: 0.021913
# loss after epoch=3: 0.016643
# loss after epoch=3: 0.016650
# loss after epoch=3: 0.009594
# loss after epoch=3: 0.018435
# loss after epoch=3: 0.011386
# loss after epoch=3: 0.014855
# loss after epoch=3: 0.016589
# loss after epoch=3: 0.018445
# loss after epoch=3: 0.025388
# loss after epoch=3: 0.011410
# loss after epoch=3: 0.021845
# loss after epoch=3: 0.020166
# loss after epoch=3: 0.018368
# loss after epoch=3: 0.009642
# loss after epoch=3: 0.014878
# loss after epoch=3: 0.018450
# loss after epoch=3: 0.011342
# loss after epoch=3: 0.016529
# loss after epoch=3: 0.023729
# loss after epoch=3: 0.018458
# loss after epoch=3: 0.020051
# loss after epoch=3: 0.014887
# loss after epoch=3: 0.016666
# loss after epoch=3: 0.020123
# loss after epoch=3: 0.016598
# loss after epoch=3: 0.018392
# loss after epoch=3: 0.016650
# loss after epoch=3: 0.016608
# loss after epoch=3: 0.018402
# loss after epoch=3: 0.018341
# loss after epoch=3: 0.016657
# loss after epoch=3: 0.020135
# loss after epoch=3: 0.018395
# loss after epoch=3: 0.018393
# loss after epoch=3: 0.014903
# loss after epoch=3: 0.018412
# loss after epoch=3: 0.021947
# loss after epoch=3: 0.018350
# loss after epoch=3: 0.016592
# loss after epoch=3: 0.011427
# loss after epoch=3: 0.018331
# loss after epoch=3: 0.023583
# loss after epoch=3: 0.016623
# loss after epoch=3: 0.014914
# loss after epoch=3: 0.013136
# loss after epoch=3: 0.018291
# loss after epoch=3: 0.016670
# loss after epoch=3: 0.025365
# loss after epoch=3: 0.014864
# loss after epoch=3: 0.013136
# loss after epoch=3: 0.013166
# loss after epoch=3: 0.013111
# loss after epoch=3: 0.009655
# loss after epoch=3: 0.013151
# loss after epoch=3: 0.018372
# loss after epoch=3: 0.023612
# loss after epoch=3: 0.018440
# loss after epoch=3: 0.009590
# loss after epoch=3: 0.013154
# loss after epoch=3: 0.014875
# loss after epoch=4: 0.014784
# loss after epoch=4: 0.021878
# loss after epoch=4: 0.016620
# loss after epoch=4: 0.016627
# loss after epoch=4: 0.009588
# loss after epoch=4: 0.018408
# loss after epoch=4: 0.011376
# loss after epoch=4: 0.014836
# loss after epoch=4: 0.016566
# loss after epoch=4: 0.018418
# loss after epoch=4: 0.025345
# loss after epoch=4: 0.011399
# loss after epoch=4: 0.021810
# loss after epoch=4: 0.020135
# loss after epoch=4: 0.018341
# loss after epoch=4: 0.009635
# loss after epoch=4: 0.014859
# loss after epoch=4: 0.018423
# loss after epoch=4: 0.011332
# loss after epoch=4: 0.016507
# loss after epoch=4: 0.023690
# loss after epoch=4: 0.018431
# loss after epoch=4: 0.020020
# loss after epoch=4: 0.014868
# loss after epoch=4: 0.016643
# loss after epoch=4: 0.020092
# loss after epoch=4: 0.016575
# loss after epoch=4: 0.018365
# loss after epoch=4: 0.016628
# loss after epoch=4: 0.016585
# loss after epoch=4: 0.018376
# loss after epoch=4: 0.018315
# loss after epoch=4: 0.016634
# loss after epoch=4: 0.020104
# loss after epoch=4: 0.018368
# loss after epoch=4: 0.018367
# loss after epoch=4: 0.014885
# loss after epoch=4: 0.018386
# loss after epoch=4: 0.021912
# loss after epoch=4: 0.018324
# loss after epoch=4: 0.016570
# loss after epoch=4: 0.011416
# loss after epoch=4: 0.018304
# loss after epoch=4: 0.023544
# loss after epoch=4: 0.016600
# loss after epoch=4: 0.014896
# loss after epoch=4: 0.013122
# loss after epoch=4: 0.018265
# loss after epoch=4: 0.016647
# loss after epoch=4: 0.025322
# loss after epoch=4: 0.014846
# loss after epoch=4: 0.013121
# loss after epoch=4: 0.013151
# loss after epoch=4: 0.013096
# loss after epoch=4: 0.009649
# loss after epoch=4: 0.013137
# loss after epoch=4: 0.018345
# loss after epoch=4: 0.023573
# loss after epoch=4: 0.018413
# loss after epoch=4: 0.009584
# loss after epoch=4: 0.013140
# loss after epoch=4: 0.014856
# loss after epoch=5: 0.014766
# loss after epoch=5: 0.021843
# loss after epoch=5: 0.016598
# loss after epoch=5: 0.016605
# loss after epoch=5: 0.009581
# loss after epoch=5: 0.018381
# loss after epoch=5: 0.011365
# loss after epoch=5: 0.014818
# loss after epoch=5: 0.016544
# loss after epoch=5: 0.018391
# loss after epoch=5: 0.025303
# loss after epoch=5: 0.011389
# loss after epoch=5: 0.021776
# loss after epoch=5: 0.020104
# loss after epoch=5: 0.018315
# loss after epoch=5: 0.009629
# loss after epoch=5: 0.014840
# loss after epoch=5: 0.018396
# loss after epoch=5: 0.011321
# loss after epoch=5: 0.016485
# loss after epoch=5: 0.023651
# loss after epoch=5: 0.018404
# loss after epoch=5: 0.019990
# loss after epoch=5: 0.014849
# loss after epoch=5: 0.016620
# loss after epoch=5: 0.020062
# loss after epoch=5: 0.016552
# loss after epoch=5: 0.018339
# loss after epoch=5: 0.016605
# loss after epoch=5: 0.016563
# loss after epoch=5: 0.018349
# loss after epoch=5: 0.018288
# loss after epoch=5: 0.016611
# loss after epoch=5: 0.020073
# loss after epoch=5: 0.018341
# loss after epoch=5: 0.018340
# loss after epoch=5: 0.014866
# loss after epoch=5: 0.018359
# loss after epoch=5: 0.021877
# loss after epoch=5: 0.018297
# loss after epoch=5: 0.016547
# loss after epoch=5: 0.011405
# loss after epoch=5: 0.018278
# loss after epoch=5: 0.023506
# loss after epoch=5: 0.016578
# loss after epoch=5: 0.014877
# loss after epoch=5: 0.013107
# loss after epoch=5: 0.018238
# loss after epoch=5: 0.016624
# loss after epoch=5: 0.025279
# loss after epoch=5: 0.014827
# loss after epoch=5: 0.013107
# loss after epoch=5: 0.013137
# loss after epoch=5: 0.013082
# loss after epoch=5: 0.009642
# loss after epoch=5: 0.013122
# loss after epoch=5: 0.018319
# loss after epoch=5: 0.023535
# loss after epoch=5: 0.018386
# loss after epoch=5: 0.009577
# loss after epoch=5: 0.013125
# loss after epoch=5: 0.014838
# loss after epoch=6: 0.014747
# loss after epoch=6: 0.021809
# loss after epoch=6: 0.016575
# loss after epoch=6: 0.016582
# loss after epoch=6: 0.009575
# loss after epoch=6: 0.018355
# loss after epoch=6: 0.011355
# loss after epoch=6: 0.014799
# loss after epoch=6: 0.016522
# loss after epoch=6: 0.018365
# loss after epoch=6: 0.025260
# loss after epoch=6: 0.011378
# loss after epoch=6: 0.021741
# loss after epoch=6: 0.020074
# loss after epoch=6: 0.018288
# loss after epoch=6: 0.009622
# loss after epoch=6: 0.014822
# loss after epoch=6: 0.018369
# loss after epoch=6: 0.011311
# loss after epoch=6: 0.016462
# loss after epoch=6: 0.023612
# loss after epoch=6: 0.018377
# loss after epoch=6: 0.019959
# loss after epoch=6: 0.014831
# loss after epoch=6: 0.016597
# loss after epoch=6: 0.020031
# loss after epoch=6: 0.016530
# loss after epoch=6: 0.018312
# loss after epoch=6: 0.016583
# loss after epoch=6: 0.016540
# loss after epoch=6: 0.018322
# loss after epoch=6: 0.018262
# loss after epoch=6: 0.016588
# loss after epoch=6: 0.020043
# loss after epoch=6: 0.018315
# loss after epoch=6: 0.018313
# loss after epoch=6: 0.014848
# loss after epoch=6: 0.018332
# loss after epoch=6: 0.021842
# loss after epoch=6: 0.018271
# loss after epoch=6: 0.016525
# loss after epoch=6: 0.011395
# loss after epoch=6: 0.018251
# loss after epoch=6: 0.023467
# loss after epoch=6: 0.016555
# loss after epoch=6: 0.014858
# loss after epoch=6: 0.013093
# loss after epoch=6: 0.018212
# loss after epoch=6: 0.016602
# loss after epoch=6: 0.025236
# loss after epoch=6: 0.014809
# loss after epoch=6: 0.013092
# loss after epoch=6: 0.013122
# loss after epoch=6: 0.013067
# loss after epoch=6: 0.009636
# loss after epoch=6: 0.013108
# loss after epoch=6: 0.018292
# loss after epoch=6: 0.023496
# loss after epoch=6: 0.018359
# loss after epoch=6: 0.009571
# loss after epoch=6: 0.013111
# loss after epoch=6: 0.014819
# loss after epoch=7: 0.014729
# loss after epoch=7: 0.021774
# loss after epoch=7: 0.016553
# loss after epoch=7: 0.016560
# loss after epoch=7: 0.009569
# loss after epoch=7: 0.018328
# loss after epoch=7: 0.011344
# loss after epoch=7: 0.014781
# loss after epoch=7: 0.016499
# loss after epoch=7: 0.018338
# loss after epoch=7: 0.025217
# loss after epoch=7: 0.011368
# loss after epoch=7: 0.021707
# loss after epoch=7: 0.020043
# loss after epoch=7: 0.018262
# loss after epoch=7: 0.009616
# loss after epoch=7: 0.014803
# loss after epoch=7: 0.018342
# loss after epoch=7: 0.011301
# loss after epoch=7: 0.016440
# loss after epoch=7: 0.023573
# loss after epoch=7: 0.018351
# loss after epoch=7: 0.019929
# loss after epoch=7: 0.014812
# loss after epoch=7: 0.016575
# loss after epoch=7: 0.020001
# loss after epoch=7: 0.016508
# loss after epoch=7: 0.018286
# loss after epoch=7: 0.016560
# loss after epoch=7: 0.016518
# loss after epoch=7: 0.018296
# loss after epoch=7: 0.018235
# loss after epoch=7: 0.016566
# loss after epoch=7: 0.020012
# loss after epoch=7: 0.018288
# loss after epoch=7: 0.018287
# loss after epoch=7: 0.014829
# loss after epoch=7: 0.018306
# loss after epoch=7: 0.021808
# loss after epoch=7: 0.018244
# loss after epoch=7: 0.016502
# loss after epoch=7: 0.011384
# loss after epoch=7: 0.018225
# loss after epoch=7: 0.023429
# loss after epoch=7: 0.016533
# loss after epoch=7: 0.014840
# loss after epoch=7: 0.013078
# loss after epoch=7: 0.018186
# loss after epoch=7: 0.016579
# loss after epoch=7: 0.025194
# loss after epoch=7: 0.014791
# loss after epoch=7: 0.013078
# loss after epoch=7: 0.013108
# loss after epoch=7: 0.013053
# loss after epoch=7: 0.009629
# loss after epoch=7: 0.013093
# loss after epoch=7: 0.018266
# loss after epoch=7: 0.023458
# loss after epoch=7: 0.018333
# loss after epoch=7: 0.009565
# loss after epoch=7: 0.013096
# loss after epoch=7: 0.014801
# loss after epoch=8: 0.014711
# loss after epoch=8: 0.021739
# loss after epoch=8: 0.016530
# loss after epoch=8: 0.016537
# loss after epoch=8: 0.009563
# loss after epoch=8: 0.018301
# loss after epoch=8: 0.011334
# loss after epoch=8: 0.014763
# loss after epoch=8: 0.016477
# loss after epoch=8: 0.018311
# loss after epoch=8: 0.025175
# loss after epoch=8: 0.011357
# loss after epoch=8: 0.021672
# loss after epoch=8: 0.020013
# loss after epoch=8: 0.018236
# loss after epoch=8: 0.009609
# loss after epoch=8: 0.014785
# loss after epoch=8: 0.018316
# loss after epoch=8: 0.011290
# loss after epoch=8: 0.016418
# loss after epoch=8: 0.023534
# loss after epoch=8: 0.018324
# loss after epoch=8: 0.019899
# loss after epoch=8: 0.014794
# loss after epoch=8: 0.016552
# loss after epoch=8: 0.019970
# loss after epoch=8: 0.016485
# loss after epoch=8: 0.018259
# loss after epoch=8: 0.016538
# loss after epoch=8: 0.016496
# loss after epoch=8: 0.018269
# loss after epoch=8: 0.018209
# loss after epoch=8: 0.016544
# loss after epoch=8: 0.019982
# loss after epoch=8: 0.018262
# loss after epoch=8: 0.018260
# loss after epoch=8: 0.014811
# loss after epoch=8: 0.018279
# loss after epoch=8: 0.021773
# loss after epoch=8: 0.018218
# loss after epoch=8: 0.016480
# loss after epoch=8: 0.011374
# loss after epoch=8: 0.018199
# loss after epoch=8: 0.023391
# loss after epoch=8: 0.016510
# loss after epoch=8: 0.014821
# loss after epoch=8: 0.013064
# loss after epoch=8: 0.018160
# loss after epoch=8: 0.016556
# loss after epoch=8: 0.025151
# loss after epoch=8: 0.014772
# loss after epoch=8: 0.013063
# loss after epoch=8: 0.013093
# loss after epoch=8: 0.013039
# loss after epoch=8: 0.009623
# loss after epoch=8: 0.013079
# loss after epoch=8: 0.018239
# loss after epoch=8: 0.023419
# loss after epoch=8: 0.018306
# loss after epoch=8: 0.009558
# loss after epoch=8: 0.013082
# loss after epoch=8: 0.014783
# loss after epoch=9: 0.014693
# loss after epoch=9: 0.021705
# loss after epoch=9: 0.016508
# loss after epoch=9: 0.016515
# loss after epoch=9: 0.009556
# loss after epoch=9: 0.018275
# loss after epoch=9: 0.011324
# loss after epoch=9: 0.014744
# loss after epoch=9: 0.016455
# loss after epoch=9: 0.018285
# loss after epoch=9: 0.025133
# loss after epoch=9: 0.011347
# loss after epoch=9: 0.021638
# loss after epoch=9: 0.019982
# loss after epoch=9: 0.018209
# loss after epoch=9: 0.009603
# loss after epoch=9: 0.014767
# loss after epoch=9: 0.018289
# loss after epoch=9: 0.011280
# loss after epoch=9: 0.016396
# loss after epoch=9: 0.023496
# loss after epoch=9: 0.018297
# loss after epoch=9: 0.019869
# loss after epoch=9: 0.014776
# loss after epoch=9: 0.016530
# loss after epoch=9: 0.019940
# loss after epoch=9: 0.016463
# loss after epoch=9: 0.018233
# loss after epoch=9: 0.016515
# loss after epoch=9: 0.016473
# loss after epoch=9: 0.018243
# loss after epoch=9: 0.018183
# loss after epoch=9: 0.016521
# loss after epoch=9: 0.019951
# loss after epoch=9: 0.018235
# loss after epoch=9: 0.018234
# loss after epoch=9: 0.014792
# loss after epoch=9: 0.018253
# loss after epoch=9: 0.021738
# loss after epoch=9: 0.018192
# loss after epoch=9: 0.016458
# loss after epoch=9: 0.011363
# loss after epoch=9: 0.018173
# loss after epoch=9: 0.023352
# loss after epoch=9: 0.016488
# loss after epoch=9: 0.014803
# loss after epoch=9: 0.013050
# loss after epoch=9: 0.018133
# loss after epoch=9: 0.016534
# loss after epoch=9: 0.025109
# loss after epoch=9: 0.014754
# loss after epoch=9: 0.013049
# loss after epoch=9: 0.013079
# loss after epoch=9: 0.013024
# loss after epoch=9: 0.009616
# loss after epoch=9: 0.013064
# loss after epoch=9: 0.018213
# loss after epoch=9: 0.023381
# loss after epoch=9: 0.018280
# loss after epoch=9: 0.009552
# loss after epoch=9: 0.013067
# loss after epoch=9: 0.014764
# loss after epoch=10: 0.014675
# loss after epoch=10: 0.021671
# loss after epoch=10: 0.016486
# loss after epoch=10: 0.016493
# loss after epoch=10: 0.009550
# loss after epoch=10: 0.018249
# loss after epoch=10: 0.011313
# loss after epoch=10: 0.014726
# loss after epoch=10: 0.016433
# loss after epoch=10: 0.018258
# loss after epoch=10: 0.025090
# loss after epoch=10: 0.011336
# loss after epoch=10: 0.021604
# loss after epoch=10: 0.019952
# loss after epoch=10: 0.018183
# loss after epoch=10: 0.009597
# loss after epoch=10: 0.014748
# loss after epoch=10: 0.018263
# loss after epoch=10: 0.011270
# loss after epoch=10: 0.016374
# loss after epoch=10: 0.023457
# loss after epoch=10: 0.018271
# loss after epoch=10: 0.019839
# loss after epoch=10: 0.014757
# loss after epoch=10: 0.016508
# loss after epoch=10: 0.019910
# loss after epoch=10: 0.016441
# loss after epoch=10: 0.018207
# loss after epoch=10: 0.016493
# loss after epoch=10: 0.016451
# loss after epoch=10: 0.018217
# loss after epoch=10: 0.018157
# loss after epoch=10: 0.016499
# loss after epoch=10: 0.019921
# loss after epoch=10: 0.018209
# loss after epoch=10: 0.018208
# loss after epoch=10: 0.014774
# loss after epoch=10: 0.018227
# loss after epoch=10: 0.021704
# loss after epoch=10: 0.018166
# loss after epoch=10: 0.016435
# loss after epoch=10: 0.011353
# loss after epoch=10: 0.018146
# loss after epoch=10: 0.023314
# loss after epoch=10: 0.016466
# loss after epoch=10: 0.014785
# loss after epoch=10: 0.013036
# loss after epoch=10: 0.018107
# loss after epoch=10: 0.016512
# loss after epoch=10: 0.025067
# loss after epoch=10: 0.014736
# loss after epoch=10: 0.013035
# loss after epoch=10: 0.013064
# loss after epoch=10: 0.013010
# loss after epoch=10: 0.009610
# loss after epoch=10: 0.013050
# loss after epoch=10: 0.018187
# loss after epoch=10: 0.023343
# loss after epoch=10: 0.018253
# loss after epoch=10: 0.009546
# loss after epoch=10: 0.013053
# loss after epoch=10: 0.014746
# loss after epoch=11: 0.014657
# loss after epoch=11: 0.021636
# loss after epoch=11: 0.016464
# loss after epoch=11: 0.016471
# loss after epoch=11: 0.009544
# loss after epoch=11: 0.018222
# loss after epoch=11: 0.011303
# loss after epoch=11: 0.014708
# loss after epoch=11: 0.016411
# loss after epoch=11: 0.018232
# loss after epoch=11: 0.025048
# loss after epoch=11: 0.011326
# loss after epoch=11: 0.021570
# loss after epoch=11: 0.019922
# loss after epoch=11: 0.018157
# loss after epoch=11: 0.009590
# loss after epoch=11: 0.014730
# loss after epoch=11: 0.018237
# loss after epoch=11: 0.011260
# loss after epoch=11: 0.016352
# loss after epoch=11: 0.023419
# loss after epoch=11: 0.018245
# loss after epoch=11: 0.019809
# loss after epoch=11: 0.014739
# loss after epoch=11: 0.016485
# loss after epoch=11: 0.019880
# loss after epoch=11: 0.016419
# loss after epoch=11: 0.018180
# loss after epoch=11: 0.016471
# loss after epoch=11: 0.016429
# loss after epoch=11: 0.018191
# loss after epoch=11: 0.018131
# loss after epoch=11: 0.016477
# loss after epoch=11: 0.019891
# loss after epoch=11: 0.018183
# loss after epoch=11: 0.018182
# loss after epoch=11: 0.014756
# loss after epoch=11: 0.018200
# loss after epoch=11: 0.021670
# loss after epoch=11: 0.018140
# loss after epoch=11: 0.016413
# loss after epoch=11: 0.011343
# loss after epoch=11: 0.018120
# loss after epoch=11: 0.023276
# loss after epoch=11: 0.016444
# loss after epoch=11: 0.014766
# loss after epoch=11: 0.013021
# loss after epoch=11: 0.018082
# loss after epoch=11: 0.016489
# loss after epoch=11: 0.025025
# loss after epoch=11: 0.014718
# loss after epoch=11: 0.013021
# loss after epoch=11: 0.013050
# loss after epoch=11: 0.012996
# loss after epoch=11: 0.009604
# loss after epoch=11: 0.013036
# loss after epoch=11: 0.018161
# loss after epoch=11: 0.023305
# loss after epoch=11: 0.018227
# loss after epoch=11: 0.009540
# loss after epoch=11: 0.013039
# loss after epoch=11: 0.014728
# loss after epoch=12: 0.014639
# loss after epoch=12: 0.021602
# loss after epoch=12: 0.016442
# loss after epoch=12: 0.016449
# loss after epoch=12: 0.009538
# loss after epoch=12: 0.018196
# loss after epoch=12: 0.011293
# loss after epoch=12: 0.014690
# loss after epoch=12: 0.016389
# loss after epoch=12: 0.018206
# loss after epoch=12: 0.025006
# loss after epoch=12: 0.011316
# loss after epoch=12: 0.021536
# loss after epoch=12: 0.019892
# loss after epoch=12: 0.018131
# loss after epoch=12: 0.009584
# loss after epoch=12: 0.014712
# loss after epoch=12: 0.018210
# loss after epoch=12: 0.011250
# loss after epoch=12: 0.016330
# loss after epoch=12: 0.023381
# loss after epoch=12: 0.018218
# loss after epoch=12: 0.019779
# loss after epoch=12: 0.014721
# loss after epoch=12: 0.016463
# loss after epoch=12: 0.019850
# loss after epoch=12: 0.016397
# loss after epoch=12: 0.018154
# loss after epoch=12: 0.016449
# loss after epoch=12: 0.016407
# loss after epoch=12: 0.018165
# loss after epoch=12: 0.018105
# loss after epoch=12: 0.016455
# loss after epoch=12: 0.019861
# loss after epoch=12: 0.018157
# loss after epoch=12: 0.018156
# loss after epoch=12: 0.014737
# loss after epoch=12: 0.018174
# loss after epoch=12: 0.021636
# loss after epoch=12: 0.018114
# loss after epoch=12: 0.016391
# loss after epoch=12: 0.011332
# loss after epoch=12: 0.018095
# loss after epoch=12: 0.023238
# loss after epoch=12: 0.016422
# loss after epoch=12: 0.014748
# loss after epoch=12: 0.013007
# loss after epoch=12: 0.018056
# loss after epoch=12: 0.016467
# loss after epoch=12: 0.024983
# loss after epoch=12: 0.014700
# loss after epoch=12: 0.013007
# loss after epoch=12: 0.013036
# loss after epoch=12: 0.012982
# loss after epoch=12: 0.009598
# loss after epoch=12: 0.013022
# loss after epoch=12: 0.018135
# loss after epoch=12: 0.023267
# loss after epoch=12: 0.018201
# loss after epoch=12: 0.009534
# loss after epoch=12: 0.013025
# loss after epoch=12: 0.014710
# loss after epoch=13: 0.014621
# loss after epoch=13: 0.021568
# loss after epoch=13: 0.016420
# loss after epoch=13: 0.016427
# loss after epoch=13: 0.009532
# loss after epoch=13: 0.018170
# loss after epoch=13: 0.011283
# loss after epoch=13: 0.014672
# loss after epoch=13: 0.016367
# loss after epoch=13: 0.018180
# loss after epoch=13: 0.024964
# loss after epoch=13: 0.011306
# loss after epoch=13: 0.021502
# loss after epoch=13: 0.019862
# loss after epoch=13: 0.018105
# loss after epoch=13: 0.009578
# loss after epoch=13: 0.014694
# loss after epoch=13: 0.018184
# loss after epoch=13: 0.011240
# loss after epoch=13: 0.016309
# loss after epoch=13: 0.023342
# loss after epoch=13: 0.018192
# loss after epoch=13: 0.019749
# loss after epoch=13: 0.014703
# loss after epoch=13: 0.016441
# loss after epoch=13: 0.019820
# loss after epoch=13: 0.016375
# loss after epoch=13: 0.018128
# loss after epoch=13: 0.016427
# loss after epoch=13: 0.016385
# loss after epoch=13: 0.018139
# loss after epoch=13: 0.018079
# loss after epoch=13: 0.016432
# loss after epoch=13: 0.019831
# loss after epoch=13: 0.018131
# loss after epoch=13: 0.018130
# loss after epoch=13: 0.014719
# loss after epoch=13: 0.018148
# loss after epoch=13: 0.021601
# loss after epoch=13: 0.018088
# loss after epoch=13: 0.016369
# loss after epoch=13: 0.011322
# loss after epoch=13: 0.018069
# loss after epoch=13: 0.023201
# loss after epoch=13: 0.016400
# loss after epoch=13: 0.014730
# loss after epoch=13: 0.012993
# loss after epoch=13: 0.018030
# loss after epoch=13: 0.016445
# loss after epoch=13: 0.024941
# loss after epoch=13: 0.014682
# loss after epoch=13: 0.012993
# loss after epoch=13: 0.013022
# loss after epoch=13: 0.012968
# loss after epoch=13: 0.009591
# loss after epoch=13: 0.013007
# loss after epoch=13: 0.018109
# loss after epoch=13: 0.023229
# loss after epoch=13: 0.018175
# loss after epoch=13: 0.009528
# loss after epoch=13: 0.013010
# loss after epoch=13: 0.014692
# loss after epoch=14: 0.014604
# loss after epoch=14: 0.021534
# loss after epoch=14: 0.016398
# loss after epoch=14: 0.016405
# loss after epoch=14: 0.009526
# loss after epoch=14: 0.018144
# loss after epoch=14: 0.011273
# loss after epoch=14: 0.014654
# loss after epoch=14: 0.016345
# loss after epoch=14: 0.018154
# loss after epoch=14: 0.024923
# loss after epoch=14: 0.011296
# loss after epoch=14: 0.021468
# loss after epoch=14: 0.019832
# loss after epoch=14: 0.018080
# loss after epoch=14: 0.009572
# loss after epoch=14: 0.014676
# loss after epoch=14: 0.018158
# loss after epoch=14: 0.011230
# loss after epoch=14: 0.016287
# loss after epoch=14: 0.023304
# loss after epoch=14: 0.018166
# loss after epoch=14: 0.019720
# loss after epoch=14: 0.014685
# loss after epoch=14: 0.016419
# loss after epoch=14: 0.019790
# loss after epoch=14: 0.016353
# loss after epoch=14: 0.018103
# loss after epoch=14: 0.016405
# loss after epoch=14: 0.016363
# loss after epoch=14: 0.018113
# loss after epoch=14: 0.018053
# loss after epoch=14: 0.016410
# loss after epoch=14: 0.019801
# loss after epoch=14: 0.018105
# loss after epoch=14: 0.018104
# loss after epoch=14: 0.014701
# loss after epoch=14: 0.018122
# loss after epoch=14: 0.021567
# loss after epoch=14: 0.018062
# loss after epoch=14: 0.016348
# loss after epoch=14: 0.011312
# loss after epoch=14: 0.018043
# loss after epoch=14: 0.023163
# loss after epoch=14: 0.016378
# loss after epoch=14: 0.014712
# loss after epoch=14: 0.012979
# loss after epoch=14: 0.018004
# loss after epoch=14: 0.016423
# loss after epoch=14: 0.024899
# loss after epoch=14: 0.014664
# loss after epoch=14: 0.012979
# loss after epoch=14: 0.013008
# loss after epoch=14: 0.012954
# loss after epoch=14: 0.009585
# loss after epoch=14: 0.012993
# loss after epoch=14: 0.018083
# loss after epoch=14: 0.023191
# loss after epoch=14: 0.018149
# loss after epoch=14: 0.009522
# loss after epoch=14: 0.012996
# loss after epoch=14: 0.014674
# loss after epoch=15: 0.014586
# loss after epoch=15: 0.021501
# loss after epoch=15: 0.016376
# loss after epoch=15: 0.016383
# loss after epoch=15: 0.009520
# loss after epoch=15: 0.018118
# loss after epoch=15: 0.011263
# loss after epoch=15: 0.014636
# loss after epoch=15: 0.016323
# loss after epoch=15: 0.018128
# loss after epoch=15: 0.024881
# loss after epoch=15: 0.011285
# loss after epoch=15: 0.021435
# loss after epoch=15: 0.019802
# loss after epoch=15: 0.018054
# loss after epoch=15: 0.009566
# loss after epoch=15: 0.014658
# loss after epoch=15: 0.018132
# loss after epoch=15: 0.011220
# loss after epoch=15: 0.016265
# loss after epoch=15: 0.023266
# loss after epoch=15: 0.018140
# loss after epoch=15: 0.019690
# loss after epoch=15: 0.014667
# loss after epoch=15: 0.016397
# loss after epoch=15: 0.019760
# loss after epoch=15: 0.016331
# loss after epoch=15: 0.018077
# loss after epoch=15: 0.016383
# loss after epoch=15: 0.016342
# loss after epoch=15: 0.018087
# loss after epoch=15: 0.018027
# loss after epoch=15: 0.016389
# loss after epoch=15: 0.019771
# loss after epoch=15: 0.018079
# loss after epoch=15: 0.018078
# loss after epoch=15: 0.014683
# loss after epoch=15: 0.018096
# loss after epoch=15: 0.021534
# loss after epoch=15: 0.018036
# loss after epoch=15: 0.016326
# loss after epoch=15: 0.011302
# loss after epoch=15: 0.018017
# loss after epoch=15: 0.023125
# loss after epoch=15: 0.016356
# loss after epoch=15: 0.014694
# loss after epoch=15: 0.012965
# loss after epoch=15: 0.017979
# loss after epoch=15: 0.016401
# loss after epoch=15: 0.024858
# loss after epoch=15: 0.014646
# loss after epoch=15: 0.012965
# loss after epoch=15: 0.012994
# loss after epoch=15: 0.012940
# loss after epoch=15: 0.009579
# loss after epoch=15: 0.012979
# loss after epoch=15: 0.018057
# loss after epoch=15: 0.023153
# loss after epoch=15: 0.018123
# loss after epoch=15: 0.009516
# loss after epoch=15: 0.012982
# loss after epoch=15: 0.014656
# loss after epoch=16: 0.014568
# loss after epoch=16: 0.021467
# loss after epoch=16: 0.016354
# loss after epoch=16: 0.016361
# loss after epoch=16: 0.009514
# loss after epoch=16: 0.018092
# loss after epoch=16: 0.011253
# loss after epoch=16: 0.014618
# loss after epoch=16: 0.016302
# loss after epoch=16: 0.018102
# loss after epoch=16: 0.024839
# loss after epoch=16: 0.011275
# loss after epoch=16: 0.021401
# loss after epoch=16: 0.019772
# loss after epoch=16: 0.018028
# loss after epoch=16: 0.009560
# loss after epoch=16: 0.014640
# loss after epoch=16: 0.018106
# loss after epoch=16: 0.011210
# loss after epoch=16: 0.016244
# loss after epoch=16: 0.023229
# loss after epoch=16: 0.018114
# loss after epoch=16: 0.019661
# loss after epoch=16: 0.014649
# loss after epoch=16: 0.016375
# loss after epoch=16: 0.019730
# loss after epoch=16: 0.016310
# loss after epoch=16: 0.018051
# loss after epoch=16: 0.016361
# loss after epoch=16: 0.016320
# loss after epoch=16: 0.018061
# loss after epoch=16: 0.018002
# loss after epoch=16: 0.016367
# loss after epoch=16: 0.019741
# loss after epoch=16: 0.018053
# loss after epoch=16: 0.018052
# loss after epoch=16: 0.014666
# loss after epoch=16: 0.018070
# loss after epoch=16: 0.021500
# loss after epoch=16: 0.018010
# loss after epoch=16: 0.016304
# loss after epoch=16: 0.011292
# loss after epoch=16: 0.017992
# loss after epoch=16: 0.023088
# loss after epoch=16: 0.016334
# loss after epoch=16: 0.014676
# loss after epoch=16: 0.012951
# loss after epoch=16: 0.017953
# loss after epoch=16: 0.016379
# loss after epoch=16: 0.024816
# loss after epoch=16: 0.014629
# loss after epoch=16: 0.012951
# loss after epoch=16: 0.012980
# loss after epoch=16: 0.012926
# loss after epoch=16: 0.009573
# loss after epoch=16: 0.012965
# loss after epoch=16: 0.018031
# loss after epoch=16: 0.023116
# loss after epoch=16: 0.018097
# loss after epoch=16: 0.009510
# loss after epoch=16: 0.012968
# loss after epoch=16: 0.014638
# loss after epoch=17: 0.014551
# loss after epoch=17: 0.021433
# loss after epoch=17: 0.016332
# loss after epoch=17: 0.016339
# loss after epoch=17: 0.009508
# loss after epoch=17: 0.018066
# loss after epoch=17: 0.011243
# loss after epoch=17: 0.014601
# loss after epoch=17: 0.016280
# loss after epoch=17: 0.018076
# loss after epoch=17: 0.024798
# loss after epoch=17: 0.011265
# loss after epoch=17: 0.021367
# loss after epoch=17: 0.019743
# loss after epoch=17: 0.018003
# loss after epoch=17: 0.009554
# loss after epoch=17: 0.014623
# loss after epoch=17: 0.018081
# loss after epoch=17: 0.011200
# loss after epoch=17: 0.016222
# loss after epoch=17: 0.023191
# loss after epoch=17: 0.018088
# loss after epoch=17: 0.019631
# loss after epoch=17: 0.014631
# loss after epoch=17: 0.016353
# loss after epoch=17: 0.019701
# loss after epoch=17: 0.016288
# loss after epoch=17: 0.018025
# loss after epoch=17: 0.016339
# loss after epoch=17: 0.016298
# loss after epoch=17: 0.018035
# loss after epoch=17: 0.017976
# loss after epoch=17: 0.016345
# loss after epoch=17: 0.019712
# loss after epoch=17: 0.018028
# loss after epoch=17: 0.018026
# loss after epoch=17: 0.014648
# loss after epoch=17: 0.018045
# loss after epoch=17: 0.021466
# loss after epoch=17: 0.017985
# loss after epoch=17: 0.016282
# loss after epoch=17: 0.011282
# loss after epoch=17: 0.017966
# loss after epoch=17: 0.023051
# loss after epoch=17: 0.016313
# loss after epoch=17: 0.014658
# loss after epoch=17: 0.012937
# loss after epoch=17: 0.017928
# loss after epoch=17: 0.016357
# loss after epoch=17: 0.024775
# loss after epoch=17: 0.014611
# loss after epoch=17: 0.012937
# loss after epoch=17: 0.012966
# loss after epoch=17: 0.012913
# loss after epoch=17: 0.009567
# loss after epoch=17: 0.012952
# loss after epoch=17: 0.018006
# loss after epoch=17: 0.023078
# loss after epoch=17: 0.018071
# loss after epoch=17: 0.009505
# loss after epoch=17: 0.012954
# loss after epoch=17: 0.014620
# loss after epoch=18: 0.014533
# loss after epoch=18: 0.021400
# loss after epoch=18: 0.016311
# loss after epoch=18: 0.016318
# loss after epoch=18: 0.009502
# loss after epoch=18: 0.018041
# loss after epoch=18: 0.011233
# loss after epoch=18: 0.014583
# loss after epoch=18: 0.016258
# loss after epoch=18: 0.018050
# loss after epoch=18: 0.024757
# loss after epoch=18: 0.011255
# loss after epoch=18: 0.021334
# loss after epoch=18: 0.019713
# loss after epoch=18: 0.017977
# loss after epoch=18: 0.009548
# loss after epoch=18: 0.014605
# loss after epoch=18: 0.018055
# loss after epoch=18: 0.011191
# loss after epoch=18: 0.016201
# loss after epoch=18: 0.023153
# loss after epoch=18: 0.018062
# loss after epoch=18: 0.019602
# loss after epoch=18: 0.014614
# loss after epoch=18: 0.016332
# loss after epoch=18: 0.019671
# loss after epoch=18: 0.016267
# loss after epoch=18: 0.018000
# loss after epoch=18: 0.016318
# loss after epoch=18: 0.016277
# loss after epoch=18: 0.018010
# loss after epoch=18: 0.017951
# loss after epoch=18: 0.016323
# loss after epoch=18: 0.019682
# loss after epoch=18: 0.018002
# loss after epoch=18: 0.018001
# loss after epoch=18: 0.014630
# loss after epoch=18: 0.018019
# loss after epoch=18: 0.021432
# loss after epoch=18: 0.017959
# loss after epoch=18: 0.016261
# loss after epoch=18: 0.011272
# loss after epoch=18: 0.017941
# loss after epoch=18: 0.023013
# loss after epoch=18: 0.016291
# loss after epoch=18: 0.014641
# loss after epoch=18: 0.012924
# loss after epoch=18: 0.017903
# loss after epoch=18: 0.016336
# loss after epoch=18: 0.024734
# loss after epoch=18: 0.014593
# loss after epoch=18: 0.012923
# loss after epoch=18: 0.012952
# loss after epoch=18: 0.012899
# loss after epoch=18: 0.009561
# loss after epoch=18: 0.012938
# loss after epoch=18: 0.017980
# loss after epoch=18: 0.023041
# loss after epoch=18: 0.018045
# loss after epoch=18: 0.009499
# loss after epoch=18: 0.012941
# loss after epoch=18: 0.014603
# loss after epoch=19: 0.014516
# loss after epoch=19: 0.021366
# loss after epoch=19: 0.016289
# loss after epoch=19: 0.016296
# loss after epoch=19: 0.009497
# loss after epoch=19: 0.018015
# loss after epoch=19: 0.011223
# loss after epoch=19: 0.014565
# loss after epoch=19: 0.016237
# loss after epoch=19: 0.018024
# loss after epoch=19: 0.024716
# loss after epoch=19: 0.011246
# loss after epoch=19: 0.021301
# loss after epoch=19: 0.019684
# loss after epoch=19: 0.017952
# loss after epoch=19: 0.009542
# loss after epoch=19: 0.014587
# loss after epoch=19: 0.018029
# loss after epoch=19: 0.011181
# loss after epoch=19: 0.016180
# loss after epoch=19: 0.023116
# loss after epoch=19: 0.018036
# loss after epoch=19: 0.019573
# loss after epoch=19: 0.014596
# loss after epoch=19: 0.016310
# loss after epoch=19: 0.019642
# loss after epoch=19: 0.016245
# loss after epoch=19: 0.017974
# loss after epoch=19: 0.016296
# loss after epoch=19: 0.016255
# loss after epoch=19: 0.017984
# loss after epoch=19: 0.017925
# loss after epoch=19: 0.016302
# loss after epoch=19: 0.019653
# loss after epoch=19: 0.017977
# loss after epoch=19: 0.017975
# loss after epoch=19: 0.014612
# loss after epoch=19: 0.017994
# loss after epoch=19: 0.021399
# loss after epoch=19: 0.017934
# loss after epoch=19: 0.016239
# loss after epoch=19: 0.011262
# loss after epoch=19: 0.017915
# loss after epoch=19: 0.022976
# loss after epoch=19: 0.016269
# loss after epoch=19: 0.014623
# loss after epoch=19: 0.012910
# loss after epoch=19: 0.017877
# loss after epoch=19: 0.016314
# loss after epoch=19: 0.024693
# loss after epoch=19: 0.014576
# loss after epoch=19: 0.012909
# loss after epoch=19: 0.012938
# loss after epoch=19: 0.012885
# loss after epoch=19: 0.009555
# loss after epoch=19: 0.012924
# loss after epoch=19: 0.017955
# loss after epoch=19: 0.023004
# loss after epoch=19: 0.018020
# loss after epoch=19: 0.009493
# loss after epoch=19: 0.012927
# loss after epoch=19: 0.014585
# loss after epoch=20: 0.014498
# loss after epoch=20: 0.021333
# loss after epoch=20: 0.016268
# loss after epoch=20: 0.016275
# loss after epoch=20: 0.009491
# loss after epoch=20: 0.017989
# loss after epoch=20: 0.011213
# loss after epoch=20: 0.014548
# loss after epoch=20: 0.016216
# loss after epoch=20: 0.017999
# loss after epoch=20: 0.024674
# loss after epoch=20: 0.011236
# loss after epoch=20: 0.021268
# loss after epoch=20: 0.019654
# loss after epoch=20: 0.017927
# loss after epoch=20: 0.009536
# loss after epoch=20: 0.014570
# loss after epoch=20: 0.018004
# loss after epoch=20: 0.011171
# loss after epoch=20: 0.016158
# loss after epoch=20: 0.023078
# loss after epoch=20: 0.018011
# loss after epoch=20: 0.019544
# loss after epoch=20: 0.014578
# loss after epoch=20: 0.016288
# loss after epoch=20: 0.019613
# loss after epoch=20: 0.016224
# loss after epoch=20: 0.017949
# loss after epoch=20: 0.016274
# loss after epoch=20: 0.016234
# loss after epoch=20: 0.017959
# loss after epoch=20: 0.017900
# loss after epoch=20: 0.016280
# loss after epoch=20: 0.019624
# loss after epoch=20: 0.017951
# loss after epoch=20: 0.017950
# loss after epoch=20: 0.014595
# loss after epoch=20: 0.017968
# loss after epoch=20: 0.021365
# loss after epoch=20: 0.017908
# loss after epoch=20: 0.016218
# loss after epoch=20: 0.011252
# loss after epoch=20: 0.017890
# loss after epoch=20: 0.022939
# loss after epoch=20: 0.016248
# loss after epoch=20: 0.014605
# loss after epoch=20: 0.012896
# loss after epoch=20: 0.017852
# loss after epoch=20: 0.016292
# loss after epoch=20: 0.024651
# loss after epoch=20: 0.014558
# loss after epoch=20: 0.012896
# loss after epoch=20: 0.012924
# loss after epoch=20: 0.012872
# loss after epoch=20: 0.009550
# loss after epoch=20: 0.012910
# loss after epoch=20: 0.017929
# loss after epoch=20: 0.022967
# loss after epoch=20: 0.017994
# loss after epoch=20: 0.009487
# loss after epoch=20: 0.012913
# loss after epoch=20: 0.014568
# loss after epoch=21: 0.014481
# loss after epoch=21: 0.021300
# loss after epoch=21: 0.016246
# loss after epoch=21: 0.016253
# loss after epoch=21: 0.009485
# loss after epoch=21: 0.017964
# loss after epoch=21: 0.011204
# loss after epoch=21: 0.014530
# loss after epoch=21: 0.016194
# loss after epoch=21: 0.017973
# loss after epoch=21: 0.024633
# loss after epoch=21: 0.011226
# loss after epoch=21: 0.021235
# loss after epoch=21: 0.019625
# loss after epoch=21: 0.017901
# loss after epoch=21: 0.009530
# loss after epoch=21: 0.014552
# loss after epoch=21: 0.017978
# loss after epoch=21: 0.011162
# loss after epoch=21: 0.016137
# loss after epoch=21: 0.023041
# loss after epoch=21: 0.017985
# loss after epoch=21: 0.019515
# loss after epoch=21: 0.014561
# loss after epoch=21: 0.016267
# loss after epoch=21: 0.019583
# loss after epoch=21: 0.016202
# loss after epoch=21: 0.017923
# loss after epoch=21: 0.016253
# loss after epoch=21: 0.016213
# loss after epoch=21: 0.017933
# loss after epoch=21: 0.017875
# loss after epoch=21: 0.016259
# loss after epoch=21: 0.019594
# loss after epoch=21: 0.017926
# loss after epoch=21: 0.017924
# loss after epoch=21: 0.014577
# loss after epoch=21: 0.017943
# loss after epoch=21: 0.021332
# loss after epoch=21: 0.017883
# loss after epoch=21: 0.016197
# loss after epoch=21: 0.011243
# loss after epoch=21: 0.017865
# loss after epoch=21: 0.022902
# loss after epoch=21: 0.016226
# loss after epoch=21: 0.014588
# loss after epoch=21: 0.012883
# loss after epoch=21: 0.017827
# loss after epoch=21: 0.016271
# loss after epoch=21: 0.024611
# loss after epoch=21: 0.014541
# loss after epoch=21: 0.012882
# loss after epoch=21: 0.012911
# loss after epoch=21: 0.012858
# loss after epoch=21: 0.009544
# loss after epoch=21: 0.012897
# loss after epoch=21: 0.017904
# loss after epoch=21: 0.022930
# loss after epoch=21: 0.017969
# loss after epoch=21: 0.009482
# loss after epoch=21: 0.012899
# loss after epoch=21: 0.014550
# loss after epoch=22: 0.014464
# loss after epoch=22: 0.021266
# loss after epoch=22: 0.016225
# loss after epoch=22: 0.016232
# loss after epoch=22: 0.009480
# loss after epoch=22: 0.017938
# loss after epoch=22: 0.011194
# loss after epoch=22: 0.014513
# loss after epoch=22: 0.016173
# loss after epoch=22: 0.017948
# loss after epoch=22: 0.024593
# loss after epoch=22: 0.011216
# loss after epoch=22: 0.021202
# loss after epoch=22: 0.019596
# loss after epoch=22: 0.017876
# loss after epoch=22: 0.009524
# loss after epoch=22: 0.014535
# loss after epoch=22: 0.017953
# loss after epoch=22: 0.011152
# loss after epoch=22: 0.016116
# loss after epoch=22: 0.023004
# loss after epoch=22: 0.017960
# loss after epoch=22: 0.019486
# loss after epoch=22: 0.014543
# loss after epoch=22: 0.016245
# loss after epoch=22: 0.019554
# loss after epoch=22: 0.016181
# loss after epoch=22: 0.017898
# loss after epoch=22: 0.016232
# loss after epoch=22: 0.016191
# loss after epoch=22: 0.017908
# loss after epoch=22: 0.017850
# loss after epoch=22: 0.016237
# loss after epoch=22: 0.019565
# loss after epoch=22: 0.017901
# loss after epoch=22: 0.017899
# loss after epoch=22: 0.014560
# loss after epoch=22: 0.017917
# loss after epoch=22: 0.021299
# loss after epoch=22: 0.017858
# loss after epoch=22: 0.016175
# loss after epoch=22: 0.011233
# loss after epoch=22: 0.017840
# loss after epoch=22: 0.022865
# loss after epoch=22: 0.016205
# loss after epoch=22: 0.014570
# loss after epoch=22: 0.012869
# loss after epoch=22: 0.017802
# loss after epoch=22: 0.016249
# loss after epoch=22: 0.024570
# loss after epoch=22: 0.014524
# loss after epoch=22: 0.012869
# loss after epoch=22: 0.012897
# loss after epoch=22: 0.012845
# loss after epoch=22: 0.009538
# loss after epoch=22: 0.012883
# loss after epoch=22: 0.017879
# loss after epoch=22: 0.022893
# loss after epoch=22: 0.017943
# loss after epoch=22: 0.009476
# loss after epoch=22: 0.012886
# loss after epoch=22: 0.014533
# loss after epoch=23: 0.014447
# loss after epoch=23: 0.021233
# loss after epoch=23: 0.016204
# loss after epoch=23: 0.016211
# loss after epoch=23: 0.009474
# loss after epoch=23: 0.017913
# loss after epoch=23: 0.011184
# loss after epoch=23: 0.014496
# loss after epoch=23: 0.016152
# loss after epoch=23: 0.017922
# loss after epoch=23: 0.024552
# loss after epoch=23: 0.011207
# loss after epoch=23: 0.021169
# loss after epoch=23: 0.019567
# loss after epoch=23: 0.017851
# loss after epoch=23: 0.009519
# loss after epoch=23: 0.014517
# loss after epoch=23: 0.017927
# loss after epoch=23: 0.011143
# loss after epoch=23: 0.016095
# loss after epoch=23: 0.022967
# loss after epoch=23: 0.017934
# loss after epoch=23: 0.019457
# loss after epoch=23: 0.014526
# loss after epoch=23: 0.016224
# loss after epoch=23: 0.019525
# loss after epoch=23: 0.016160
# loss after epoch=23: 0.017873
# loss after epoch=23: 0.016210
# loss after epoch=23: 0.016170
# loss after epoch=23: 0.017883
# loss after epoch=23: 0.017825
# loss after epoch=23: 0.016216
# loss after epoch=23: 0.019536
# loss after epoch=23: 0.017876
# loss after epoch=23: 0.017874
# loss after epoch=23: 0.014542
# loss after epoch=23: 0.017892
# loss after epoch=23: 0.021266
# loss after epoch=23: 0.017833
# loss after epoch=23: 0.016154
# loss after epoch=23: 0.011223
# loss after epoch=23: 0.017815
# loss after epoch=23: 0.022829
# loss after epoch=23: 0.016184
# loss after epoch=23: 0.014553
# loss after epoch=23: 0.012856
# loss after epoch=23: 0.017777
# loss after epoch=23: 0.016228
# loss after epoch=23: 0.024529
# loss after epoch=23: 0.014506
# loss after epoch=23: 0.012855
# loss after epoch=23: 0.012883
# loss after epoch=23: 0.012831
# loss after epoch=23: 0.009532
# loss after epoch=23: 0.012869
# loss after epoch=23: 0.017854
# loss after epoch=23: 0.022856
# loss after epoch=23: 0.017918
# loss after epoch=23: 0.009471
# loss after epoch=23: 0.012872
# loss after epoch=23: 0.014515
# loss after epoch=24: 0.014430
# loss after epoch=24: 0.021200
# loss after epoch=24: 0.016183
# loss after epoch=24: 0.016190
# loss after epoch=24: 0.009469
# loss after epoch=24: 0.017888
# loss after epoch=24: 0.011175
# loss after epoch=24: 0.014478
# loss after epoch=24: 0.016131
# loss after epoch=24: 0.017897
# loss after epoch=24: 0.024511
# loss after epoch=24: 0.011197
# loss after epoch=24: 0.021136
# loss after epoch=24: 0.019538
# loss after epoch=24: 0.017826
# loss after epoch=24: 0.009513
# loss after epoch=24: 0.014500
# loss after epoch=24: 0.017902
# loss after epoch=24: 0.011133
# loss after epoch=24: 0.016074
# loss after epoch=24: 0.022930
# loss after epoch=24: 0.017909
# loss after epoch=24: 0.019428
# loss after epoch=24: 0.014509
# loss after epoch=24: 0.016203
# loss after epoch=24: 0.019496
# loss after epoch=24: 0.016139
# loss after epoch=24: 0.017848
# loss after epoch=24: 0.016189
# loss after epoch=24: 0.016149
# loss after epoch=24: 0.017858
# loss after epoch=24: 0.017800
# loss after epoch=24: 0.016195
# loss after epoch=24: 0.019507
# loss after epoch=24: 0.017850
# loss after epoch=24: 0.017849
# loss after epoch=24: 0.014525
# loss after epoch=24: 0.017867
# loss after epoch=24: 0.021233
# loss after epoch=24: 0.017808
# loss after epoch=24: 0.016133
# loss after epoch=24: 0.011213
# loss after epoch=24: 0.017790
# loss after epoch=24: 0.022792
# loss after epoch=24: 0.016163
# loss after epoch=24: 0.014535
# loss after epoch=24: 0.012842
# loss after epoch=24: 0.017752
# loss after epoch=24: 0.016207
# loss after epoch=24: 0.024488
# loss after epoch=24: 0.014489
# loss after epoch=24: 0.012842
# loss after epoch=24: 0.012870
# loss after epoch=24: 0.012818
# loss after epoch=24: 0.009527
# loss after epoch=24: 0.012856
# loss after epoch=24: 0.017829
# loss after epoch=24: 0.022819
# loss after epoch=24: 0.017893
# loss after epoch=24: 0.009465
# loss after epoch=24: 0.012859
# loss after epoch=24: 0.014498
# loss after epoch=25: 0.014413
# loss after epoch=25: 0.021167
# loss after epoch=25: 0.016161
# loss after epoch=25: 0.016169
# loss after epoch=25: 0.009463
# loss after epoch=25: 0.017863
# loss after epoch=25: 0.011165
# loss after epoch=25: 0.014461
# loss after epoch=25: 0.016110
# loss after epoch=25: 0.017872
# loss after epoch=25: 0.024471
# loss after epoch=25: 0.011187
# loss after epoch=25: 0.021103
# loss after epoch=25: 0.019509
# loss after epoch=25: 0.017801
# loss after epoch=25: 0.009507
# loss after epoch=25: 0.014483
# loss after epoch=25: 0.017877
# loss after epoch=25: 0.011124
# loss after epoch=25: 0.016053
# loss after epoch=25: 0.022893
# loss after epoch=25: 0.017884
# loss after epoch=25: 0.019399
# loss after epoch=25: 0.014491
# loss after epoch=25: 0.016182
# loss after epoch=25: 0.019467
# loss after epoch=25: 0.016118
# loss after epoch=25: 0.017823
# loss after epoch=25: 0.016168
# loss after epoch=25: 0.016128
# loss after epoch=25: 0.017833
# loss after epoch=25: 0.017775
# loss after epoch=25: 0.016173
# loss after epoch=25: 0.019478
# loss after epoch=25: 0.017825
# loss after epoch=25: 0.017824
# loss after epoch=25: 0.014507
# loss after epoch=25: 0.017842
# loss after epoch=25: 0.021200
# loss after epoch=25: 0.017783
# loss after epoch=25: 0.016112
# loss after epoch=25: 0.011204
# loss after epoch=25: 0.017765
# loss after epoch=25: 0.022755
# loss after epoch=25: 0.016142
# loss after epoch=25: 0.014518
# loss after epoch=25: 0.012829
# loss after epoch=25: 0.017727
# loss after epoch=25: 0.016185
# loss after epoch=25: 0.024448
# loss after epoch=25: 0.014472
# loss after epoch=25: 0.012828
# loss after epoch=25: 0.012856
# loss after epoch=25: 0.012805
# loss after epoch=25: 0.009521
# loss after epoch=25: 0.012843
# loss after epoch=25: 0.017804
# loss after epoch=25: 0.022783
# loss after epoch=25: 0.017868
# loss after epoch=25: 0.009460
# loss after epoch=25: 0.012845
# loss after epoch=25: 0.014481
# loss after epoch=26: 0.014396
# loss after epoch=26: 0.021135
# loss after epoch=26: 0.016140
# loss after epoch=26: 0.016148
# loss after epoch=26: 0.009458
# loss after epoch=26: 0.017838
# loss after epoch=26: 0.011156
# loss after epoch=26: 0.014444
# ...
# loss after epoch=91: 0.017750
# loss after epoch=91: 0.014884
# loss after epoch=91: 0.016343
# loss after epoch=91: 0.014927
# loss after epoch=91: 0.014893
# loss after epoch=91: 0.016351
# loss after epoch=91: 0.016303
# loss after epoch=91: 0.014930
# loss after epoch=91: 0.017758
# loss after epoch=91: 0.016346
# loss after epoch=91: 0.016343
# loss after epoch=91: 0.013504
# loss after epoch=91: 0.016358
# loss after epoch=91: 0.019230
# loss after epoch=91: 0.016308
# loss after epoch=91: 0.014877
# loss after epoch=91: 0.010678
# loss after epoch=91: 0.016295
# loss after epoch=91: 0.020563
# loss after epoch=91: 0.014904
# loss after epoch=91: 0.013514
# loss after epoch=91: 0.012069
# loss after epoch=91: 0.016263
# loss after epoch=91: 0.014939
# loss after epoch=91: 0.022011
# loss after epoch=91: 0.013479
# loss after epoch=91: 0.012069
# loss after epoch=91: 0.012091
# loss after epoch=91: 0.012049
# loss after epoch=91: 0.009239
# loss after epoch=91: 0.012080
# loss after epoch=91: 0.016326
# loss after epoch=91: 0.020586
# loss after epoch=91: 0.016379
# loss after epoch=91: 0.009188
# loss after epoch=91: 0.012082
# loss after epoch=91: 0.013482
# loss after epoch=92: 0.013414
# loss after epoch=92: 0.019175
# loss after epoch=92: 0.014906
# loss after epoch=92: 0.014914
# loss after epoch=92: 0.009186
# loss after epoch=92: 0.016355
# loss after epoch=92: 0.010637
# loss after epoch=92: 0.013452
# loss after epoch=92: 0.014862
# loss after epoch=92: 0.016360
# loss after epoch=92: 0.021997
# loss after epoch=92: 0.010655
# loss after epoch=92: 0.019120
# loss after epoch=92: 0.017762
# loss after epoch=92: 0.016308
# loss after epoch=92: 0.009222
# loss after epoch=92: 0.013471
# loss after epoch=92: 0.016367
# loss after epoch=92: 0.010604
# loss after epoch=92: 0.014814
# loss after epoch=92: 0.020649
# loss after epoch=92: 0.016370
# loss after epoch=92: 0.017670
# loss after epoch=92: 0.013478
# loss after epoch=92: 0.014919
# loss after epoch=92: 0.017726
# loss after epoch=92: 0.014867
# loss after epoch=92: 0.016323
# loss after epoch=92: 0.014910
# loss after epoch=92: 0.014877
# loss after epoch=92: 0.016331
# loss after epoch=92: 0.016283
# loss after epoch=92: 0.014914
# loss after epoch=92: 0.017734
# loss after epoch=92: 0.016326
# loss after epoch=92: 0.016323
# loss after epoch=92: 0.013491
# loss after epoch=92: 0.016338
# loss after epoch=92: 0.019203
# loss after epoch=92: 0.016288
# loss after epoch=92: 0.014861
# loss after epoch=92: 0.010672
# loss after epoch=92: 0.016275
# loss after epoch=92: 0.020533
# loss after epoch=92: 0.014887
# loss after epoch=92: 0.013501
# loss after epoch=92: 0.012060
# loss after epoch=92: 0.016243
# loss after epoch=92: 0.014922
# loss after epoch=92: 0.021977
# loss after epoch=92: 0.013466
# loss after epoch=92: 0.012059
# loss after epoch=92: 0.012081
# loss after epoch=92: 0.012039
# loss after epoch=92: 0.009236
# loss after epoch=92: 0.012070
# loss after epoch=92: 0.016306
# loss after epoch=92: 0.020556
# loss after epoch=92: 0.016359
# loss after epoch=92: 0.009185
# loss after epoch=92: 0.012072
# loss after epoch=92: 0.013469
# loss after epoch=93: 0.013402
# loss after epoch=93: 0.019148
# loss after epoch=93: 0.014889
# loss after epoch=93: 0.014898
# loss after epoch=93: 0.009184
# loss after epoch=93: 0.016335
# loss after epoch=93: 0.010631
# loss after epoch=93: 0.013439
# loss after epoch=93: 0.014845
# loss after epoch=93: 0.016340
# loss after epoch=93: 0.021964
# loss after epoch=93: 0.010649
# loss after epoch=93: 0.019094
# loss after epoch=93: 0.017738
# loss after epoch=93: 0.016288
# loss after epoch=93: 0.009219
# loss after epoch=93: 0.013458
# loss after epoch=93: 0.016347
# loss after epoch=93: 0.010598
# loss after epoch=93: 0.014797
# loss after epoch=93: 0.020619
# loss after epoch=93: 0.016350
# loss after epoch=93: 0.017647
# loss after epoch=93: 0.013465
# loss after epoch=93: 0.014903
# loss after epoch=93: 0.017703
# loss after epoch=93: 0.014851
# loss after epoch=93: 0.016303
# loss after epoch=93: 0.014894
# loss after epoch=93: 0.014860
# loss after epoch=93: 0.016311
# loss after epoch=93: 0.016263
# loss after epoch=93: 0.014897
# loss after epoch=93: 0.017711
# loss after epoch=93: 0.016306
# loss after epoch=93: 0.016303
# loss after epoch=93: 0.013478
# loss after epoch=93: 0.016318
# loss after epoch=93: 0.019176
# loss after epoch=93: 0.016268
# loss after epoch=93: 0.014844
# loss after epoch=93: 0.010665
# loss after epoch=93: 0.016256
# loss after epoch=93: 0.020503
# loss after epoch=93: 0.014871
# loss after epoch=93: 0.013488
# loss after epoch=93: 0.012050
# loss after epoch=93: 0.016223
# loss after epoch=93: 0.014905
# loss after epoch=93: 0.021944
# loss after epoch=93: 0.013453
# loss after epoch=93: 0.012050
# loss after epoch=93: 0.012071
# loss after epoch=93: 0.012030
# loss after epoch=93: 0.009233
# loss after epoch=93: 0.012060
# loss after epoch=93: 0.016287
# loss after epoch=93: 0.020526
# loss after epoch=93: 0.016339
# loss after epoch=93: 0.009182
# loss after epoch=93: 0.012062
# loss after epoch=93: 0.013456
# loss after epoch=94: 0.013389
# loss after epoch=94: 0.019121
# loss after epoch=94: 0.014873
# loss after epoch=94: 0.014881
# loss after epoch=94: 0.009181
# loss after epoch=94: 0.016315
# loss after epoch=94: 0.010625
# loss after epoch=94: 0.013426
# loss after epoch=94: 0.014829
# loss after epoch=94: 0.016320
# loss after epoch=94: 0.021930
# loss after epoch=94: 0.010642
# loss after epoch=94: 0.019067
# loss after epoch=94: 0.017715
# loss after epoch=94: 0.016269
# loss after epoch=94: 0.009216
# loss after epoch=94: 0.013445
# loss after epoch=94: 0.016327
# loss after epoch=94: 0.010591
# loss after epoch=94: 0.014781
# loss after epoch=94: 0.020589
# loss after epoch=94: 0.016330
# loss after epoch=94: 0.017624
# loss after epoch=94: 0.013451
# loss after epoch=94: 0.014886
# loss after epoch=94: 0.017680
# loss after epoch=94: 0.014834
# loss after epoch=94: 0.016283
# loss after epoch=94: 0.014877
# loss after epoch=94: 0.014844
# loss after epoch=94: 0.016291
# loss after epoch=94: 0.016243
# loss after epoch=94: 0.014881
# loss after epoch=94: 0.017688
# loss after epoch=94: 0.016286
# loss after epoch=94: 0.016283
# loss after epoch=94: 0.013465
# loss after epoch=94: 0.016298
# loss after epoch=94: 0.019149
# loss after epoch=94: 0.016248
# loss after epoch=94: 0.014828
# loss after epoch=94: 0.010659
# loss after epoch=94: 0.016236
# loss after epoch=94: 0.020473
# loss after epoch=94: 0.014854
# loss after epoch=94: 0.013475
# loss after epoch=94: 0.012040
# loss after epoch=94: 0.016204
# loss after epoch=94: 0.014889
# loss after epoch=94: 0.021911
# loss after epoch=94: 0.013440
# loss after epoch=94: 0.012040
# loss after epoch=94: 0.012061
# loss after epoch=94: 0.012020
# loss after epoch=94: 0.009230
# loss after epoch=94: 0.012051
# loss after epoch=94: 0.016267
# loss after epoch=94: 0.020496
# loss after epoch=94: 0.016319
# loss after epoch=94: 0.009179
# loss after epoch=94: 0.012053
# loss after epoch=94: 0.013443
# loss after epoch=95: 0.013376
# loss after epoch=95: 0.019095
# loss after epoch=95: 0.014857
# loss after epoch=95: 0.014865
# loss after epoch=95: 0.009178
# loss after epoch=95: 0.016295
# loss after epoch=95: 0.010618
# loss after epoch=95: 0.013413
# loss after epoch=95: 0.014813
# loss after epoch=95: 0.016300
# loss after epoch=95: 0.021897
# loss after epoch=95: 0.010636
# loss after epoch=95: 0.019041
# loss after epoch=95: 0.017692
# loss after epoch=95: 0.016249
# loss after epoch=95: 0.009214
# loss after epoch=95: 0.013432
# loss after epoch=95: 0.016307
# loss after epoch=95: 0.010585
# loss after epoch=95: 0.014765
# loss after epoch=95: 0.020558
# loss after epoch=95: 0.016310
# loss after epoch=95: 0.017601
# loss after epoch=95: 0.013438
# loss after epoch=95: 0.014870
# loss after epoch=95: 0.017657
# loss after epoch=95: 0.014818
# loss after epoch=95: 0.016263
# loss after epoch=95: 0.014861
# loss after epoch=95: 0.014828
# loss after epoch=95: 0.016271
# loss after epoch=95: 0.016224
# loss after epoch=95: 0.014864
# loss after epoch=95: 0.017665
# loss after epoch=95: 0.016266
# loss after epoch=95: 0.016263
# loss after epoch=95: 0.013452
# loss after epoch=95: 0.016278
# loss after epoch=95: 0.019123
# loss after epoch=95: 0.016228
# loss after epoch=95: 0.014812
# loss after epoch=95: 0.010653
# loss after epoch=95: 0.016216
# loss after epoch=95: 0.020444
# loss after epoch=95: 0.014838
# loss after epoch=95: 0.013462
# loss after epoch=95: 0.012031
# loss after epoch=95: 0.016184
# loss after epoch=95: 0.014872
# loss after epoch=95: 0.021877
# loss after epoch=95: 0.013427
# loss after epoch=95: 0.012030
# loss after epoch=95: 0.012052
# loss after epoch=95: 0.012011
# loss after epoch=95: 0.009227
# loss after epoch=95: 0.012041
# loss after epoch=95: 0.016247
# loss after epoch=95: 0.020466
# loss after epoch=95: 0.016299
# loss after epoch=95: 0.009177
# loss after epoch=95: 0.012043
# loss after epoch=95: 0.013430
# loss after epoch=96: 0.013363
# loss after epoch=96: 0.019068
# loss after epoch=96: 0.014840
# loss after epoch=96: 0.014848
# loss after epoch=96: 0.009175
# loss after epoch=96: 0.016275
# loss after epoch=96: 0.010612
# loss after epoch=96: 0.013400
# loss after epoch=96: 0.014796
# loss after epoch=96: 0.016280
# loss after epoch=96: 0.021864
# loss after epoch=96: 0.010630
# loss after epoch=96: 0.019014
# loss after epoch=96: 0.017669
# loss after epoch=96: 0.016229
# loss after epoch=96: 0.009211
# loss after epoch=96: 0.013419
# loss after epoch=96: 0.016288
# loss after epoch=96: 0.010579
# loss after epoch=96: 0.014749
# loss after epoch=96: 0.020528
# loss after epoch=96: 0.016290
# loss after epoch=96: 0.017578
# loss after epoch=96: 0.013426
# loss after epoch=96: 0.014853
# loss after epoch=96: 0.017634
# loss after epoch=96: 0.014802
# loss after epoch=96: 0.016244
# loss after epoch=96: 0.014844
# loss after epoch=96: 0.014812
# loss after epoch=96: 0.016252
# loss after epoch=96: 0.016204
# loss after epoch=96: 0.014848
# loss after epoch=96: 0.017642
# loss after epoch=96: 0.016246
# loss after epoch=96: 0.016243
# loss after epoch=96: 0.013439
# loss after epoch=96: 0.016259
# loss after epoch=96: 0.019096
# loss after epoch=96: 0.016209
# loss after epoch=96: 0.014795
# loss after epoch=96: 0.010646
# loss after epoch=96: 0.016197
# loss after epoch=96: 0.020414
# loss after epoch=96: 0.014822
# loss after epoch=96: 0.013449
# loss after epoch=96: 0.012021
# loss after epoch=96: 0.016165
# loss after epoch=96: 0.014856
# loss after epoch=96: 0.021844
# loss after epoch=96: 0.013414
# loss after epoch=96: 0.012021
# loss after epoch=96: 0.012042
# loss after epoch=96: 0.012001
# loss after epoch=96: 0.009224
# loss after epoch=96: 0.012031
# loss after epoch=96: 0.016227
# loss after epoch=96: 0.020436
# loss after epoch=96: 0.016280
# loss after epoch=96: 0.009174
# loss after epoch=96: 0.012033
# loss after epoch=96: 0.013417
# loss after epoch=97: 0.013350
# loss after epoch=97: 0.019042
# loss after epoch=97: 0.014824
# loss after epoch=97: 0.014832
# loss after epoch=97: 0.009172
# loss after epoch=97: 0.016255
# loss after epoch=97: 0.010606
# loss after epoch=97: 0.013387
# loss after epoch=97: 0.014780
# loss after epoch=97: 0.016261
# loss after epoch=97: 0.021831
# loss after epoch=97: 0.010624
# loss after epoch=97: 0.018988
# loss after epoch=97: 0.017646
# loss after epoch=97: 0.016210
# loss after epoch=97: 0.009208
# loss after epoch=97: 0.013406
# loss after epoch=97: 0.016268
# loss after epoch=97: 0.010573
# loss after epoch=97: 0.014733
# loss after epoch=97: 0.020499
# loss after epoch=97: 0.016270
# loss after epoch=97: 0.017555
# loss after epoch=97: 0.013413
# loss after epoch=97: 0.014837
# loss after epoch=97: 0.017611
# loss after epoch=97: 0.014786
# loss after epoch=97: 0.016224
# loss after epoch=97: 0.014828
# loss after epoch=97: 0.014795
# loss after epoch=97: 0.016232
# loss after epoch=97: 0.016185
# loss after epoch=97: 0.014832
# loss after epoch=97: 0.017619
# loss after epoch=97: 0.016227
# loss after epoch=97: 0.016224
# loss after epoch=97: 0.013426
# loss after epoch=97: 0.016239
# loss after epoch=97: 0.019070
# loss after epoch=97: 0.016189
# loss after epoch=97: 0.014779
# loss after epoch=97: 0.010640
# loss after epoch=97: 0.016177
# loss after epoch=97: 0.020384
# loss after epoch=97: 0.014805
# loss after epoch=97: 0.013436
# loss after epoch=97: 0.012012
# loss after epoch=97: 0.016145
# loss after epoch=97: 0.014840
# loss after epoch=97: 0.021811
# loss after epoch=97: 0.013402
# loss after epoch=97: 0.012011
# loss after epoch=97: 0.012032
# loss after epoch=97: 0.011992
# loss after epoch=97: 0.009221
# loss after epoch=97: 0.012022
# loss after epoch=97: 0.016208
# loss after epoch=97: 0.020407
# loss after epoch=97: 0.016260
# loss after epoch=97: 0.009171
# loss after epoch=97: 0.012024
# loss after epoch=97: 0.013404
# loss after epoch=98: 0.013338
# loss after epoch=98: 0.019016
# loss after epoch=98: 0.014808
# loss after epoch=98: 0.014816
# loss after epoch=98: 0.009170
# loss after epoch=98: 0.016236
# loss after epoch=98: 0.010600
# loss after epoch=98: 0.013374
# loss after epoch=98: 0.014764
# loss after epoch=98: 0.016241
# loss after epoch=98: 0.021798
# loss after epoch=98: 0.010617
# loss after epoch=98: 0.018962
# loss after epoch=98: 0.017623
# loss after epoch=98: 0.016190
# loss after epoch=98: 0.009205
# loss after epoch=98: 0.013393
# loss after epoch=98: 0.016248
# loss after epoch=98: 0.010567
# loss after epoch=98: 0.014717
# loss after epoch=98: 0.020469
# loss after epoch=98: 0.016251
# loss after epoch=98: 0.017532
# loss after epoch=98: 0.013400
# loss after epoch=98: 0.014821
# loss after epoch=98: 0.017588
# loss after epoch=98: 0.014770
# loss after epoch=98: 0.016204
# loss after epoch=98: 0.014812
# loss after epoch=98: 0.014779
# loss after epoch=98: 0.016212
# loss after epoch=98: 0.016165
# loss after epoch=98: 0.014816
# loss after epoch=98: 0.017596
# loss after epoch=98: 0.016207
# loss after epoch=98: 0.016204
# loss after epoch=98: 0.013413
# loss after epoch=98: 0.016219
# loss after epoch=98: 0.019043
# loss after epoch=98: 0.016170
# loss after epoch=98: 0.014763
# loss after epoch=98: 0.010634
# loss after epoch=98: 0.016158
# loss after epoch=98: 0.020355
# loss after epoch=98: 0.014789
# loss after epoch=98: 0.013423
# loss after epoch=98: 0.012002
# loss after epoch=98: 0.016126
# loss after epoch=98: 0.014823
# loss after epoch=98: 0.021778
# loss after epoch=98: 0.013389
# loss after epoch=98: 0.012002
# loss after epoch=98: 0.012023
# loss after epoch=98: 0.011982
# loss after epoch=98: 0.009219
# loss after epoch=98: 0.012012
# loss after epoch=98: 0.016188
# loss after epoch=98: 0.020377
# loss after epoch=98: 0.016240
# loss after epoch=98: 0.009169
# loss after epoch=98: 0.012014
# loss after epoch=98: 0.013391
# loss after epoch=99: 0.013325
# loss after epoch=99: 0.018989
# loss after epoch=99: 0.014792
# loss after epoch=99: 0.014800
# loss after epoch=99: 0.009167
# loss after epoch=99: 0.016216
# loss after epoch=99: 0.010594
# loss after epoch=99: 0.013361
# loss after epoch=99: 0.014748
# loss after epoch=99: 0.016221
# loss after epoch=99: 0.021765
# loss after epoch=99: 0.010611
# loss after epoch=99: 0.018936
# loss after epoch=99: 0.017600
# loss after epoch=99: 0.016171
# loss after epoch=99: 0.009202
# loss after epoch=99: 0.013380
# loss after epoch=99: 0.016229
# loss after epoch=99: 0.010561
# loss after epoch=99: 0.014701
# loss after epoch=99: 0.020439
# loss after epoch=99: 0.016231
# loss after epoch=99: 0.017510
# loss after epoch=99: 0.013387
# loss after epoch=99: 0.014805
# loss after epoch=99: 0.017565
# loss after epoch=99: 0.014754
# loss after epoch=99: 0.016185
# loss after epoch=99: 0.014796
# loss after epoch=99: 0.014763
# loss after epoch=99: 0.016193
# loss after epoch=99: 0.016146
# loss after epoch=99: 0.014799
# loss after epoch=99: 0.017573
# loss after epoch=99: 0.016188
# loss after epoch=99: 0.016185
# loss after epoch=99: 0.013400
# loss after epoch=99: 0.016200
# loss after epoch=99: 0.019017
# loss after epoch=99: 0.016150
# loss after epoch=99: 0.014747
# loss after epoch=99: 0.010628
# loss after epoch=99: 0.016138
# loss after epoch=99: 0.020326
# loss after epoch=99: 0.014773
# loss after epoch=99: 0.013410
# loss after epoch=99: 0.011993
# loss after epoch=99: 0.016107
# loss after epoch=99: 0.014807
# loss after epoch=99: 0.021746
# loss after epoch=99: 0.013376
# loss after epoch=99: 0.011992
# loss after epoch=99: 0.012013
# loss after epoch=99: 0.011973
# loss after epoch=99: 0.009216
# loss after epoch=99: 0.012003
# loss after epoch=99: 0.016169
# loss after epoch=99: 0.020348
# loss after epoch=99: 0.016221
# loss after epoch=99: 0.009166
# loss after epoch=99: 0.012005
# loss after epoch=99: 0.013379

# %%
inputDim = 10
n = 1000
X = np.random.rand(n,inputDim)
y = np.random.randint(0,2,n)

# %%
X.shape
# Out:
# (1000, 10)

# %%
y.shape
# Out:
# (1000,)

# %%
np.unique(y)
# Out:
# array([0, 1])

# %%
W = torch.tensor(np.random.uniform(0,1,inputDim),requires_grad=True)

# %%
z = wSum(X[0,:],W)

# %%
print(z)
# Out:
# tensor(2.6729, dtype=torch.float64, grad_fn=<DotBackward0>)

# %%
inputDim = 10
n = 1000
X = np.random.rand(n,inputDim)
y = np.random.randint(0,2,n)

W1 = torch.tensor(np.random.uniform(0,1,(2,inputDim)),requires_grad=True)
W2 = torch.tensor(np.random.uniform(0,1,(3,2)),requires_grad=True)
W3 = torch.tensor(np.random.uniform(0,1,3),requires_grad=True)

W_list = []
W_list.append(W1)
W_list.append(W2)
W_list.append(W3)

z = forwardStep(X[0,:],W_list)
print(z)
# Out:
# tensor(0.7439, dtype=torch.float64, grad_fn=<MulBackward0>)

# %%
#activation_fun = nn.Sigmoid()
activation_fun = nn.ReLU()
x = 100*torch.randn(1)
y = torch.randint(0,2,(1,),dtype=torch.float)
y_hat = activation_fun(x)
loss_fun = nn.BCELoss()
loss_value = loss_fun(y_hat,y)
print(loss_value.item())
#print(x,activation_fun(x))
# Out:
# 100.0

# %%
print(y_hat,y)
# Out:
# tensor([0.]) tensor([1.])

# %%
m = nn.Sigmoid()
loss_fun = nn.BCELoss()
lr = 0.0001
x = torch.randn(1)
y = torch.randint(0,2,(1,),dtype=torch.float)
w = torch.randn(1,requires_grad=True)

# %%
nIter = 100
for i in range(nIter):
    y_hat = m(w*x)
    loss = loss_fun(y_hat,y)
    loss.backward()
    dw = w.grad.data
    with torch.no_grad():
        w -= lr*dw
    w.grad.data.zero_()
    print(loss.item())
# Out:
# 1.3076229095458984
# 1.307604193687439
# 1.30758535861969
# 1.3075666427612305
# 1.307547926902771
# 1.3075292110443115
# 1.3075100183486938
# 1.3074913024902344
# 1.307472586631775
# 1.3074536323547363
# 1.3074349164962769
# 1.3074162006378174
# 1.3073972463607788
# 1.3073785305023193
# 1.3073595762252808
# 1.3073408603668213
# 1.3073221445083618
# 1.3073031902313232
# 1.3072844743728638
# 1.3072655200958252
# 1.3072468042373657
# 1.3072280883789062
# 1.3072091341018677
# 1.3071904182434082
# 1.3071715831756592
# 1.307152509689331
# 1.3071337938308716
# 1.307115077972412
# 1.3070963621139526
# 1.3070775270462036
# 1.3070586919784546
# 1.3070399761199951
# 1.307021141052246
# 1.307002067565918
# 1.3069833517074585
# 1.306964635848999
# 1.3069459199905396
# 1.306926965713501
# 1.3069082498550415
# 1.306889533996582
# 1.3068703413009644
# 1.3068516254425049
# 1.3068329095840454
# 1.306814193725586
# 1.3067952394485474
# 1.306776523590088
# 1.3067578077316284
# 1.3067388534545898
# 1.3067201375961304
# 1.3067011833190918
# 1.3066824674606323
# 1.3066636323928833
# 1.3066449165344238
# 1.3066259622573853
# 1.3066072463989258
# 1.3065885305404663
# 1.3065698146820068
# 1.3065506219863892
# 1.3065319061279297
# 1.3065129518508911
# 1.3064942359924316
# 1.3064755201339722
# 1.3064568042755127
# 1.3064379692077637
# 1.3064192533493042
# 1.3064002990722656
# 1.3063815832138062
# 1.3063626289367676
# 1.306343913078308
# 1.3063249588012695
# 1.3063063621520996
# 1.306287407875061
# 1.3062686920166016
# 1.306249976158142
# 1.3062310218811035
# 1.306212306022644
# 1.3061933517456055
# 1.3061745166778564
# 1.306155800819397
# 1.3061368465423584
# 1.306118130683899
# 1.3060994148254395
# 1.3060805797576904
# 1.306061863899231
# 1.3060431480407715
# 1.306024193763733
# 1.3060054779052734
# 1.3059865236282349
# 1.3059678077697754
# 1.3059492111206055
# 1.3059300184249878
# 1.3059113025665283
# 1.3058923482894897
# 1.3058737516403198
# 1.3058550357818604
# 1.3058360815048218
# 1.3058173656463623
# 1.3057984113693237
# 1.3057798147201538
# 1.3057610988616943

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
inputDim = 10
n = 1000
X = np.random.rand(n,inputDim)
y = np.random.randint(0,2,n)

tensor_x = torch.Tensor(X)
tensor_y = torch.Tensor(y)

Xy = TensorDataset(tensor_x,tensor_y)
Xy_loader = DataLoader(Xy,batch_size=16,shuffle=True,drop_last=True)

# %%
model = nn.Sequential(
    nn.Linear(inputDim,200),
    nn.ReLU(),
    nn.Linear(200,100),
    nn.Tanh(),
    nn.Linear(100,1),
    nn.Sigmoid()
)

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)

# %%
loss_fn = nn.BCELoss()

# %%
nepochs = 100
for epoch in range(nepochs):
    for X,y in Xy_loader:
        batch_size = X.shape[0]
        y_hat = model(X.view(batch_size,-1))
        loss = loss_fn(y_hat, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(float(loss))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19701/2459630794.py in <module>
#       4         batch_size = X.shape[0]
#       5         y_hat = model(X.view(batch_size,-1))
# ----> 6         loss = loss_fn(y_hat, y)
#       7         optimizer.zero_grad()
#       8         loss.backward()
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     601
#     602     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 603         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     604
#     605
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2904         reduction_enum = _Reduction.get_enum(reduction)
#    2905     if target.size() != input.size():
# -> 2906         raise ValueError(
#    2907             "Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    2908             "Please ensure they have the same size.".format(target.size(), input.size())
#
# ValueError: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1])) is deprecated. Please ensure they have the same size.

# %%
with torch.no_grad():
    xt = torch.tensor(np.random.rand(1,inputDim))
    y2 = model(xt.float())
    print(y2.detach().numpy()[0][0])
