# %%
import pandas as pd
from generate_fake_dataframe import generate_fake_dataframe

# %%
df = generate_fake_dataframe(size = 1000, cols =  "cififficcd")
df
# Out:
#     column_0_cat  column_1_int  column_2_float  column_3_int  column_4_float  \
# 0      Elizabeth             0       47.003409             5       29.008340
# 1           John             4       86.123946             7       44.396545
# 2           John             8        5.217385             4       13.498149
# 3          Ahmed             2       11.492142             0       46.425555
# 4      Elizabeth             3        4.440187             9       72.574482
# ..           ...           ...             ...           ...             ...
# 995    Elizabeth             1       37.742252             5       87.713762
# 996    Elizabeth             0       77.019288             3       28.413179
# 997         John             6       96.077695             6        4.140863
# 998      Michael             3       73.673260             3       41.208295
# 999      Michael             7       96.443506             2       94.070148
#
# ...

# %%
from generate_fake_dataframe_pl import generate_fake_dataframe

# %%
df = generate_fake_dataframe(size = 1000, cols =  "cififficcd")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_274819/4168969641.py in <module>
# ----> 1 df = generate_fake_dataframe(size = 1000, cols =  "cififficcd")
#       2 df
#
# ~/repo/data_science_journey/course_ds/notebooks/generate_fake_dataframe_pl.py in generate_fake_dataframe(size, cols, col_names, intervals, seed)
#      51             df[col_name] = rng.choice(categories, size, shuffle = True)
#      52         elif col == "d":
# ---> 53             df[col_name] = rng.choice(pl.date_range(start, end), size)
#      54     return df
#
# TypeError: date_range() missing 1 required positional argument: 'interval'
