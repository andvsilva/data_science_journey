# %%
import numpy as np
import matplotlib.pyplot as plt

import os

# %%
# see what we have in our current working directory
os.system('ls -lash')
# Out:
# total 5,6M
# 4,0K drwxrwxr-x 2 andsilva andsilva 4,0K mar  1 10:53 .
# 4,0K drwxrwxr-x 6 andsilva andsilva 4,0K mar  1 10:45 ..
# 5,2M -rw-rw-r-- 1 andsilva andsilva 5,2M abr 29  2016 bird.png
# 332K -rw-rw-r-- 1 andsilva andsilva 330K mar  2 09:24 work_img.ipynb
# 0

# %%
# read the image
img = plt.imread('bird.png')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (8000, 6368, 4)

# %%
img1 = img[:,:,:3]
img1.shape
# Out:
# (8000, 6368, 3)

# %%
R = img1[:,:,0]
G = img1[:,:,1]
B = img1[:,:,2]

# %%
plt.imshow(R, cmap='gray')

# %%
plt.imshow(G, cmap='gray')

# %%
plt.imshow(B, cmap='gray')

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize=(10,15))
ax1.imshow(R,cmap='gray')
ax2.imshow(G,cmap='gray')
ax3.imshow(B,cmap='gray')

# %%
img2 = img1.copy()
img2[:,:,2] = 255

# %%
plt.imshow(img2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img3 = img2.copy()
img3[100:600,100:600,0] = 255
img3[100:600,100:600,1] = 0
img3[100:600,100:600,2] = 0

plt.imshow(img3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img = plt.imread('bird.png')
